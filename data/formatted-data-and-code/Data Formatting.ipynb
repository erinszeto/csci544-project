# %% [markdown]
# # Data Formatting

# %%
import json
import os
import pandas as pd
import nltk
import re
nltk.download('punkt')
from nltk.tokenize import sent_tokenize, word_tokenize, TweetTokenizer
from progressbar import ProgressBar
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/daniellesim/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## CRS Files

# %% [markdown]
# Example instance

# %%
f = open('gov-report/crs/95-118.json',)
example = json.load(f)
f.close()

# %%
def flattenParagraph(paragraphList): 
    
    sentences = sent_tokenize(' '.join(paragraphList))
    sentences = [s.lower() for s in sentences]
    length = len(sentences)
    
    return(sentences, length)

# %%
def sectionInfo(file): 
    
    # initialize vectors that will later be part of formatted file
    section_names = []
    section_lengths = []
    
    # first section and content from file 
    section_names.append(file['reports']['section_title'].lower()) 
    section_lengths.append(flattenParagraph(file['reports']['paragraphs'])[1])
    content = flattenParagraph(file['reports']['paragraphs'])[0]
    
    # iterate and parse through all subsections and append to vectors 
    for d in file['reports']['subsections']:
    
        section_names.append(d['section_title'].lower())
        section_lengths.append(flattenParagraph(d['paragraphs'])[1])
        content = content + flattenParagraph(d['paragraphs'])[0]
    
    if d['subsections'] != []: 
        for s in d['subsections']: 
            section_names.append(s['section_title'].lower())
            section_lengths.append(flattenParagraph(s['paragraphs'])[1])
            content = content + flattenParagraph(s['paragraphs'])[0]
        
            if s['subsections'] != []: 
                for n in s['subsections']: 
                    section_names.append(n['section_title'].lower())
                    section_lengths.append(flattenParagraph(n['paragraphs'])[1])
                    content = content + flattenParagraph(n['paragraphs'])[0]
                    
                    if n['subsections'] != []: 
                        for t in n['subsections']: 
                            section_names.append(t['section_title'].lower())
                            section_lengths.append(flattenParagraph(t['paragraphs'])[1])
                            content = content + flattenParagraph(t['paragraphs'])[0]
                            
    return(section_names, section_lengths, content)

# %%
tknzr = TweetTokenizer()
def finalFormatting(file, section_names, section_lengths, content): 
    # initialize sentence 
    sentence_id = 1

    # initialize final formatted dictionary structure
    formatted = {} 
    formatted['id'] = file['id']
    formatted['inputs'] = []

    # iterate through sentences 
    for sentence in content: 
        sent = {} 
        sentence_clean = re.sub('([!?(–)—;-<->/])', r' \1 ', sentence)  # pad basic punctuation with whitespace
        sentence_clean = re.sub('.$', ' .', sentence_clean)  # pad ending period with whitespace
        sentence_clean = re.sub(' - - ', ' -- ', sentence_clean)  # cleaning up instances of -- 
        sentence_clean = re.sub(r'([0-9]) - ', r'\1-', sentence_clean)  # keeping number-word instances together
        sentence_clean = re.sub(', ', ' , ', sentence_clean)  # padding commas in sentences but not in numbers
        sentence_clean = re.sub('’', '\'', sentence_clean)  # replacing apostrophe font
        sentence_clean = re.sub(' +', ' ', sentence_clean).rstrip()  # remove double white spice and space at end
        sent['text']  = sentence_clean
        sent['tokens'] = word_tokenize(sentence_clean)
        sent['sentence_id'] = sentence_id
        sent['word_count'] = len(word_tokenize(sentence_clean))
        formatted['inputs'].append(sent)
        sentence_id += 1
        
    # add information from previous section
    formatted['section_names'] = section_names
    formatted['section_lengths'] = section_lengths
        
    return(formatted)

# %%
finalFormatting(example, sectionInfo(example)[0], sectionInfo(example)[1], sectionInfo(example)[2])
# Out:
# {'id': '95-118',
#  'inputs': [{'text': 'the pension benefit guaranty corporation ( pbgc ) is a federal agency established by the employee retirement income security act of 1974 ( erisa ; p.l .',
#    'tokens': ['the',
#     'pension',
#     'benefit',
#     'guaranty',
#     'corporation',
#     '(',
#     'pbgc',
#     ')',
#     'is',
#     'a',
#     'federal',
#     'agency',
#     'established',
#     'by',
#     'the',
#     'employee',
#     'retirement',
#     'income',
#     'security',
#     'act',
#     'of',
#     '1974',
#     '(',
#     'erisa',
#     ';',
#     'p.l',
#     '.'],
#    'sentence_id': 1,
#    'word_count': 27},
#   {'text': '93-406 ) .',
#    'tokens': ['93-406', ')', '.'],
#    'sentence_id': 2,
#    'word_count': 3},
#   {'text': 'it was created to protect the pe nsions of participants and beneficiaries covered by private sector defined benefit ( db ) plans .',
#    'tokens': ['it',
#     'was',
#     'created',
#     'to',
#     'protect',
#     'the',
#     'pe',
#     'nsions',
#     'of',
#     'participants',
#     'and',
#     'beneficiaries',
#     'covered',
#     'by',
#     'private',
#     'sector',
#     'defined',
#     'benefit',
#     '(',
#     'db',
#     ')',
#     'plans',
#     '.'],
#    'sentence_id': 3,
#    'word_count': 23},
#   {'text': 'these pension plans provide a specified monthly benefit at retirement , usually either a percentage of salary or a flat dollar amount multiplied by years of service .',
#    'tokens': ['these',
#     'pension',
#     'plans',
#     'provide',
#     'a',
#     'specified',
#     'monthly',
#     'benefit',
#     'at',
#     'retirement',
#     ',',
#     'usually',
#     'either',
#     'a',
#     'percentage',
#     'of',
#     'salary',
#     'or',
#     'a',
#     'flat',
#     'dollar',
#     'amount',
#     'multiplied',
#     'by',
#     'years',
#     'of',
#     'service',
#     '.'],
#    'sentence_id': 4,
#    'word_count': 28},
#   {'text': 'defined contribution ( dc ) plans , such as 401 ( k ) plans , are not insured .',
#    'tokens': ['defined',
#     'contribution',
#     '(',
#     'dc',
#     ')',
#     'plans',
#     ',',
#     'such',
#     'as',
#     '401',
#     '(',
#     'k',
#     ')',
#     'plans',
#     ',',
#     'are',
#     'not',
#     'insured',
#     '.'],
#    'sentence_id': 5,
#    'word_count': 19},
#   {'text': 'pbgc runs two distinct insurance programs: one for single - employer pension plans and a second for multiemployer plans .',
#    'tokens': ['pbgc',
#     'runs',
#     'two',
#     'distinct',
#     'insurance',
#     'programs',
#     ':',
#     'one',
#     'for',
#     'single',
#     '-',
#     'employer',
#     'pension',
#     'plans',
#     'and',
#     'a',
#     'second',
#     'for',
#     'multiemployer',
#     'plans',
#     '.'],
#    'sentence_id': 6,
#    'word_count': 21},
#   {'text': 'single - employer pension plans are sponsored by one employer and cover eligible workers employed by the plan sponsor .',
#    'tokens': ['single',
#     '-',
#     'employer',
#     'pension',
#     'plans',
#     'are',
#     'sponsored',
#     'by',
#     'one',
#     'employer',
#     'and',
#     'cover',
#     'eligible',
#     'workers',
#     'employed',
#     'by',
#     'the',
#     'plan',
#     'sponsor',
#     '.'],
#    'sentence_id': 7,
#    'word_count': 20},
#   {'text': 'multiemployer plans are collectively bargained plans to which more than one company makes contributions .',
#    'tokens': ['multiemployer',
#     'plans',
#     'are',
#     'collectively',
#     'bargained',
#     'plans',
#     'to',
#     'which',
#     'more',
#     'than',
#     'one',
#     'company',
#     'makes',
#     'contributions',
#     '.'],
#    'sentence_id': 8,
#    'word_count': 15},
#   {'text': 'pbgc maintains separate reserve funds for each program .',
#    'tokens': ['pbgc',
#     'maintains',
#     'separate',
#     'reserve',
#     'funds',
#     'for',
#     'each',
#     'program',
#     '.'],
#    'sentence_id': 9,
#    'word_count': 9},
#   {'text': 'in fy2018 , pbgc insured about 25,000 db pension plans covering about 37 million people .',
#    'tokens': ['in',
#     'fy2018',
#     ',',
#     'pbgc',
#     'insured',
#     'about',
#     '25,000',
#     'db',
#     'pension',
#     'plans',
#     'covering',
#     'about',
#     '37',
#     'million',
#     'people',
#     '.'],
#    'sentence_id': 10,
#    'word_count': 16},
#   {'text': 'it paid or owed benefits to 1.4 million people .',
#    'tokens': ['it',
#     'paid',
#     'or',
#     'owed',
#     'benefits',
#     'to',
#     '1.4',
#     'million',
#     'people',
#     '.'],
#    'sentence_id': 11,
#    'word_count': 10},
#   {'text': 'pbgc is the trustee of 4,919 single - employer plans .',
#    'tokens': ['pbgc',
#     'is',
#     'the',
#     'trustee',
#     'of',
#     '4,919',
#     'single',
#     '-',
#     'employer',
#     'plans',
#     '.'],
#    'sentence_id': 12,
#    'word_count': 11},
#   {'text': 'pbgc provided financial assistance to 78 multiemployer pensions .',
#    'tokens': ['pbgc',
#     'provided',
#     'financial',
#     'assistance',
#     'to',
#     '78',
#     'multiemployer',
#     'pensions',
#     '.'],
#    'sentence_id': 13,
#    'word_count': 9},
#   {'text': 'pbgc pays a maximum benefit to plan participants .',
#    'tokens': ['pbgc',
#     'pays',
#     'a',
#     'maximum',
#     'benefit',
#     'to',
#     'plan',
#     'participants',
#     '.'],
#    'sentence_id': 14,
#    'word_count': 9},
#   {'text': 'most workers in single - employer plans taken over by pbgc and multiemployer plans that receive financial assistance from pbgc receive the full pension benefit that they earned .',
#    'tokens': ['most',
#     'workers',
#     'in',
#     'single',
#     '-',
#     'employer',
#     'plans',
#     'taken',
#     'over',
#     'by',
#     'pbgc',
#     'and',
#     'multiemployer',
#     'plans',
#     'that',
#     'receive',
#     'financial',
#     'assistance',
#     'from',
#     'pbgc',
#     'receive',
#     'the',
#     'full',
#     'pension',
#     'benefit',
#     'that',
#     'they',
#     'earned',
#     '.'],
#    'sentence_id': 15,
#    'word_count': 29},
#   {'text': 'however , among participants in multiemployer plans that were terminated and likely to need financial assistance in the future , 49% have a benefit below the pbgc maximum guarantee and 51% have a benefit larger than the pbgc maximum guarantee .',
#    'tokens': ['however',
#     ',',
#     'among',
#     'participants',
#     'in',
#     'multiemployer',
#     'plans',
#     'that',
#     'were',
#     'terminated',
#     'and',
#     'likely',
#     'to',
#     'need',
#     'financial',
#     'assistance',
#     'in',
#     'the',
#     'future',
#     ',',
#     '49',
#     '%',
#     'have',
#     'a',
#     'benefit',
#     'below',
#     'the',
#     'pbgc',
#     'maximum',
#     'guarantee',
#     'and',
#     '51',
#     '%',
#     'have',
#     'a',
#     'benefit',
#     'larger',
#     'than',
#     'the',
#     'pbgc',
#     'maximum',
#     'guarantee',
#     '.'],
#    'sentence_id': 16,
#    'word_count': 43},
#   {'text': 'pbgc is a government - owned corporation .',
#    'tokens': ['pbgc',
#     'is',
#     'a',
#     'government',
#     '-',
#     'owned',
#     'corporation',
#     '.'],
#    'sentence_id': 17,
#    'word_count': 8},
#   {'text': 'a three - member board of directors , chaired by the secretary of labor , administers the corporation .',
#    'tokens': ['a',
#     'three',
#     '-',
#     'member',
#     'board',
#     'of',
#     'directors',
#     ',',
#     'chaired',
#     'by',
#     'the',
#     'secretary',
#     'of',
#     'labor',
#     ',',
#     'administers',
#     'the',
#     'corporation',
#     '.'],
#    'sentence_id': 18,
#    'word_count': 19},
#   {'text': 'the secretary of commerce and the secretary of the treasury are the other members of the board of directors .',
#    'tokens': ['the',
#     'secretary',
#     'of',
#     'commerce',
#     'and',
#     'the',
#     'secretary',
#     'of',
#     'the',
#     'treasury',
#     'are',
#     'the',
#     'other',
#     'members',
#     'of',
#     'the',
#     'board',
#     'of',
#     'directors',
#     '.'],
#    'sentence_id': 19,
#    'word_count': 20},
#   {'text': 'the director of pbgc is appointed by the president with the advice and consent of the senate .',
#    'tokens': ['the',
#     'director',
#     'of',
#     'pbgc',
#     'is',
#     'appointed',
#     'by',
#     'the',
#     'president',
#     'with',
#     'the',
#     'advice',
#     'and',
#     'consent',
#     'of',
#     'the',
#     'senate',
#     '.'],
#    'sentence_id': 20,
#    'word_count': 18},
#   {'text': 'erisa also provides for a seven - member advisory committee , appointed by the president , for staggered three - year terms .',
#    'tokens': ['erisa',
#     'also',
#     'provides',
#     'for',
#     'a',
#     'seven',
#     '-',
#     'member',
#     'advisory',
#     'committee',
#     ',',
#     'appointed',
#     'by',
#     'the',
#     'president',
#     ',',
#     'for',
#     'staggered',
#     'three',
#     '-',
#     'year',
#     'terms',
#     '.'],
#    'sentence_id': 21,
#    'word_count': 23},
#   {'text': 'the advisory committee advises pbgc on issues , such as investment of funds , plan liquidations , and other matters .',
#    'tokens': ['the',
#     'advisory',
#     'committee',
#     'advises',
#     'pbgc',
#     'on',
#     'issues',
#     ',',
#     'such',
#     'as',
#     'investment',
#     'of',
#     'funds',
#     ',',
#     'plan',
#     'liquidations',
#     ',',
#     'and',
#     'other',
#     'matters',
#     '.'],
#    'sentence_id': 22,
#    'word_count': 21},
#   {'text': 'the moving ahead for progress in the 21 st century act ( map - 21 ; p.l .',
#    'tokens': ['the',
#     'moving',
#     'ahead',
#     'for',
#     'progress',
#     'in',
#     'the',
#     '21',
#     'st',
#     'century',
#     'act',
#     '(',
#     'map',
#     '-',
#     '21',
#     ';',
#     'p.l',
#     '.'],
#    'sentence_id': 23,
#    'word_count': 18},
#   {'text': '112-141 ) altered some of the governance structures of pbgc .',
#    'tokens': ['112-141',
#     ')',
#     'altered',
#     'some',
#     'of',
#     'the',
#     'governance',
#     'structures',
#     'of',
#     'pbgc',
#     '.'],
#    'sentence_id': 24,
#    'word_count': 11},
#   {'text': 'some of these changes include setting the term of the pbgc director at five years , unless removed by the president or by the board of directors ; requiring that the board of directors meet at least four times each year ; and establishing a participant and plan sponsor advocate within pbgc to act as a liaison between pbgc , participants in plans trusteed by pbgc , and the sponsors of pension plans insured by pbgc .',
#    'tokens': ['some',
#     'of',
#     'these',
#     'changes',
#     'include',
#     'setting',
#     'the',
#     'term',
#     'of',
#     'the',
#     'pbgc',
#     'director',
#     'at',
#     'five',
#     'years',
#     ',',
#     'unless',
#     'removed',
#     'by',
#     'the',
#     'president',
#     'or',
#     'by',
#     'the',
#     'board',
#     'of',
#     'directors',
#     ';',
#     'requiring',
#     'that',
#     'the',
#     'board',
#     'of',
#     'directors',
#     'meet',
#     'at',
#     'least',
#     'four',
#     'times',
#     'each',
#     'year',
#     ';',
#     'and',
#     'establishing',
#     'a',
#     'participant',
#     'and',
#     'plan',
#     'sponsor',
#     'advocate',
#     'within',
#     'pbgc',
#     'to',
#     'act',
#     'as',
#     'a',
#     'liaison',
#     'between',
#     'pbgc',
#     ',',
#     'participants',
#     'in',
#     'plans',
#     'trusteed',
#     'by',
#     'pbgc',
#     ',',
#     'and',
#     'the',
#     'sponsors',
#     'of',
#     'pension',
#     'plans',
#     'insured',
#     'by',
#     'pbgc',
#     '.'],
#    'sentence_id': 25,
#    'word_count': 77},
#   {'text': 'pbgc is required by erisa to be self - supporting and receives no appropriations from general revenue .',
#    'tokens': ['pbgc',
#     'is',
#     'required',
#     'by',
#     'erisa',
#     'to',
#     'be',
#     'self',
#     '-',
#     'supporting',
#     'and',
#     'receives',
#     'no',
#     'appropriations',
#     'from',
#     'general',
#     'revenue',
#     '.'],
#    'sentence_id': 26,
#    'word_count': 18},
#   {'text': 'erisa states that the "united states is not liable for any obligation or liability incurred by the corporation," and some members of congress have expressed a reluctance to consider providing financial assistance to pbgc .',
#    'tokens': ['erisa',
#     'states',
#     'that',
#     'the',
#     '``',
#     'united',
#     'states',
#     'is',
#     'not',
#     'liable',
#     'for',
#     'any',
#     'obligation',
#     'or',
#     'liability',
#     'incurred',
#     'by',
#     'the',
#     'corporation',
#     ',',
#     "''",
#     'and',
#     'some',
#     'members',
#     'of',
#     'congress',
#     'have',
#     'expressed',
#     'a',
#     'reluctance',
#     'to',
#     'consider',
#     'providing',
#     'financial',
#     'assistance',
#     'to',
#     'pbgc',
#     '.'],
#    'sentence_id': 27,
#    'word_count': 38},
#   {'text': 'the most reliable source of pbgc revenue is the premiums set by congress and paid by the private - sector employers that sponsor db pension plans .',
#    'tokens': ['the',
#     'most',
#     'reliable',
#     'source',
#     'of',
#     'pbgc',
#     'revenue',
#     'is',
#     'the',
#     'premiums',
#     'set',
#     'by',
#     'congress',
#     'and',
#     'paid',
#     'by',
#     'the',
#     'private',
#     '-',
#     'sector',
#     'employers',
#     'that',
#     'sponsor',
#     'db',
#     'pension',
#     'plans',
#     '.'],
#    'sentence_id': 28,
#    'word_count': 27},
#   {'text': 'other sources of income are assets from terminated plans taken over by pbgc , investment income , and recoveries collected from companies when they end underfunded pension plans .',
#    'tokens': ['other',
#     'sources',
#     'of',
#     'income',
#     'are',
#     'assets',
#     'from',
#     'terminated',
#     'plans',
#     'taken',
#     'over',
#     'by',
#     'pbgc',
#     ',',
#     'investment',
#     'income',
#     ',',
#     'and',
#     'recoveries',
#     'collected',
#     'from',
#     'companies',
#     'when',
#     'they',
#     'end',
#     'underfunded',
#     'pension',
#     'plans',
#     '.'],
#    'sentence_id': 29,
#    'word_count': 29},
#   {'text': 'the multiemployer pension plan amendments act of 1980 ( p.l .',
#    'tokens': ['the',
#     'multiemployer',
#     'pension',
#     'plan',
#     'amendments',
#     'act',
#     'of',
#     '1980',
#     '(',
#     'p.l',
#     '.'],
#    'sentence_id': 30,
#    'word_count': 11},
#   {'text': "96-364 ) requires that pbgc's receipts and disbursements be included in federal budget totals .",
#    'tokens': ['96-364',
#     ')',
#     'requires',
#     'that',
#     'pbgc',
#     "'s",
#     'receipts',
#     'and',
#     'disbursements',
#     'be',
#     'included',
#     'in',
#     'federal',
#     'budget',
#     'totals',
#     '.'],
#    'sentence_id': 31,
#    'word_count': 16},
#   {'text': 'the sponsors of private - sector pension plans pay a variety of premiums to pbgc .',
#    'tokens': ['the',
#     'sponsors',
#     'of',
#     'private',
#     '-',
#     'sector',
#     'pension',
#     'plans',
#     'pay',
#     'a',
#     'variety',
#     'of',
#     'premiums',
#     'to',
#     'pbgc',
#     '.'],
#    'sentence_id': 32,
#    'word_count': 16},
#   {'text': 'the sponsors of single - employer and multiemployer pension plans pay a flat - rate , per - participant premium .',
#    'tokens': ['the',
#     'sponsors',
#     'of',
#     'single',
#     '-',
#     'employer',
#     'and',
#     'multiemployer',
#     'pension',
#     'plans',
#     'pay',
#     'a',
#     'flat',
#     '-',
#     'rate',
#     ',',
#     'per',
#     '-',
#     'participant',
#     'premium',
#     '.'],
#    'sentence_id': 33,
#    'word_count': 21},
#   {'text': 'the sponsors of underfunded single - employer pension plans pay an additional premium that is based on the amount of plan underfunding .',
#    'tokens': ['the',
#     'sponsors',
#     'of',
#     'underfunded',
#     'single',
#     '-',
#     'employer',
#     'pension',
#     'plans',
#     'pay',
#     'an',
#     'additional',
#     'premium',
#     'that',
#     'is',
#     'based',
#     'on',
#     'the',
#     'amount',
#     'of',
#     'plan',
#     'underfunding',
#     '.'],
#    'sentence_id': 34,
#    'word_count': 23},
#   {'text': 'in addition , pension plans that are terminated in certain situations pay a per - participant premium per year for three years after termination .',
#    'tokens': ['in',
#     'addition',
#     ',',
#     'pension',
#     'plans',
#     'that',
#     'are',
#     'terminated',
#     'in',
#     'certain',
#     'situations',
#     'pay',
#     'a',
#     'per',
#     '-',
#     'participant',
#     'premium',
#     'per',
#     'year',
#     'for',
#     'three',
#     'years',
#     'after',
#     'termination',
#     '.'],
#    'sentence_id': 35,
#    'word_count': 25},
#   {'text': 'the premiums for 2019 are as follows: single - employer flat - rate premium : the sponsors of single - employer db pension plans pay an annual premium of $80 for each participant in the plan .',
#    'tokens': ['the',
#     'premiums',
#     'for',
#     '2019',
#     'are',
#     'as',
#     'follows',
#     ':',
#     'single',
#     '-',
#     'employer',
#     'flat',
#     '-',
#     'rate',
#     'premium',
#     ':',
#     'the',
#     'sponsors',
#     'of',
#     'single',
#     '-',
#     'employer',
#     'db',
#     'pension',
#     'plans',
#     'pay',
#     'an',
#     'annual',
#     'premium',
#     'of',
#     '$',
#     '80',
#     'for',
#     'each',
#     'participant',
#     'in',
#     'the',
#     'plan',
#     '.'],
#    'sentence_id': 36,
#    'word_count': 39},
#   {'text': 'single - employer variable - rate premium : in addition to the flat - rate premium , the sponsors of underfunded single - employer db pension plans pay an additional annual premium of $43 for each $1,000 of unfunded vested benefits .',
#    'tokens': ['single',
#     '-',
#     'employer',
#     'variable',
#     '-',
#     'rate',
#     'premium',
#     ':',
#     'in',
#     'addition',
#     'to',
#     'the',
#     'flat',
#     '-',
#     'rate',
#     'premium',
#     ',',
#     'the',
#     'sponsors',
#     'of',
#     'underfunded',
#     'single',
#     '-',
#     'employer',
#     'db',
#     'pension',
#     'plans',
#     'pay',
#     'an',
#     'additional',
#     'annual',
#     'premium',
#     'of',
#     '$',
#     '43',
#     'for',
#     'each',
#     '$',
#     '1,000',
#     'of',
#     'unfunded',
#     'vested',
#     'benefits',
#     '.'],
#    'sentence_id': 37,
#    'word_count': 44},
#   {'text': 'there is a per - participant limit of $541 for this premium .',
#    'tokens': ['there',
#     'is',
#     'a',
#     'per',
#     '-',
#     'participant',
#     'limit',
#     'of',
#     '$',
#     '541',
#     'for',
#     'this',
#     'premium',
#     '.'],
#    'sentence_id': 38,
#    'word_count': 14},
#   {'text': 'single - employer termination premium : the sponsors of single - employer db pension plans that end in certain situations pay an annual premium of $1,250 per participant per year for three years following plan termination .',
#    'tokens': ['single',
#     '-',
#     'employer',
#     'termination',
#     'premium',
#     ':',
#     'the',
#     'sponsors',
#     'of',
#     'single',
#     '-',
#     'employer',
#     'db',
#     'pension',
#     'plans',
#     'that',
#     'end',
#     'in',
#     'certain',
#     'situations',
#     'pay',
#     'an',
#     'annual',
#     'premium',
#     'of',
#     '$',
#     '1,250',
#     'per',
#     'participant',
#     'per',
#     'year',
#     'for',
#     'three',
#     'years',
#     'following',
#     'plan',
#     'termination',
#     '.'],
#    'sentence_id': 39,
#    'word_count': 38},
#   {'text': 'multiemployer flat - rate premium : the sponsors of multiemployer db pension plans pay an annual premium of $29 for each participant in the plan in 2019 .',
#    'tokens': ['multiemployer',
#     'flat',
#     '-',
#     'rate',
#     'premium',
#     ':',
#     'the',
#     'sponsors',
#     'of',
#     'multiemployer',
#     'db',
#     'pension',
#     'plans',
#     'pay',
#     'an',
#     'annual',
#     'premium',
#     'of',
#     '$',
#     '29',
#     'for',
#     'each',
#     'participant',
#     'in',
#     'the',
#     'plan',
#     'in',
#     '2019',
#     '.'],
#    'sentence_id': 40,
#    'word_count': 29},
#   {'text': 'in the appendix , table a - 1 and table a - 2 provide a history of pbgc premium rates .',
#    'tokens': ['in',
#     'the',
#     'appendix',
#     ',',
#     'table',
#     'a',
#     '-',
#     '1',
#     'and',
#     'table',
#     'a',
#     '-',
#     '2',
#     'provide',
#     'a',
#     'history',
#     'of',
#     'pbgc',
#     'premium',
#     'rates',
#     '.'],
#    'sentence_id': 41,
#    'word_count': 21},
#   {'text': 'table 1 details the amounts of premium income in fy2017 and fy2018 .',
#    'tokens': ['table',
#     '1',
#     'details',
#     'the',
#     'amounts',
#     'of',
#     'premium',
#     'income',
#     'in',
#     'fy2017',
#     'and',
#     'fy2018',
#     '.'],
#    'sentence_id': 42,
#    'word_count': 13},
#   {'text': 'pbgc covers only those db plans that meet the qualification requirements of section 401 of the internal revenue code ( irc ) .',
#    'tokens': ['pbgc',
#     'covers',
#     'only',
#     'those',
#     'db',
#     'plans',
#     'that',
#     'meet',
#     'the',
#     'qualification',
#     'requirements',
#     'of',
#     'section',
#     '401',
#     'of',
#     'the',
#     'internal',
#     'revenue',
#     'code',
#     '(',
#     'irc',
#     ')',
#     '.'],
#    'sentence_id': 43,
#    'word_count': 23},
#   {'text': 'dc plans ( such as 401 ( k ) and 403 ( b ) plans ) are not insured by pbgc .',
#    'tokens': ['dc',
#     'plans',
#     '(',
#     'such',
#     'as',
#     '401',
#     '(',
#     'k',
#     ')',
#     'and',
#     '403',
#     '(',
#     'b',
#     ')',
#     'plans',
#     ')',
#     'are',
#     'not',
#     'insured',
#     'by',
#     'pbgc',
#     '.'],
#    'sentence_id': 44,
#    'word_count': 22},
#   {'text': 'plans must meet these requirements to receive the tax benefits available to qualified pension plans .',
#    'tokens': ['plans',
#     'must',
#     'meet',
#     'these',
#     'requirements',
#     'to',
#     'receive',
#     'the',
#     'tax',
#     'benefits',
#     'available',
#     'to',
#     'qualified',
#     'pension',
#     'plans',
#     '.'],
#    'sentence_id': 45,
#    'word_count': 16},
#   {'text': "if a plan meets the requirements of irc section 401 , the employer's contributions to the plan are treated as a tax - deductible business expense , and neither the employer's contributions to the plan nor the investment earnings of the plan are treated as taxable income to the participants .",
#    'tokens': ['if',
#     'a',
#     'plan',
#     'meets',
#     'the',
#     'requirements',
#     'of',
#     'irc',
#     'section',
#     '401',
#     ',',
#     'the',
#     'employer',
#     "'s",
#     'contributions',
#     'to',
#     'the',
#     'plan',
#     'are',
#     'treated',
#     'as',
#     'a',
#     'tax',
#     '-',
#     'deductible',
#     'business',
#     'expense',
#     ',',
#     'and',
#     'neither',
#     'the',
#     'employer',
#     "'s",
#     'contributions',
#     'to',
#     'the',
#     'plan',
#     'nor',
#     'the',
#     'investment',
#     'earnings',
#     'of',
#     'the',
#     'plan',
#     'are',
#     'treated',
#     'as',
#     'taxable',
#     'income',
#     'to',
#     'the',
#     'participants',
#     '.'],
#    'sentence_id': 46,
#    'word_count': 53},
#   {'text': 'when a pension plan participant begins to receive income from the plan , it is taxed as ordinary income .',
#    'tokens': ['when',
#     'a',
#     'pension',
#     'plan',
#     'participant',
#     'begins',
#     'to',
#     'receive',
#     'income',
#     'from',
#     'the',
#     'plan',
#     ',',
#     'it',
#     'is',
#     'taxed',
#     'as',
#     'ordinary',
#     'income',
#     '.'],
#    'sentence_id': 47,
#    'word_count': 20},
#   {'text': 'in general , to be qualified under the irc , a pension plan must be established with the intent of being a permanent and continuing arrangement ; must provide definitely determinable benefits ; may not discriminate in favor of highly compensated employees with respect to coverage , contributions , or benefits ; and must cover a minimum number or percentage of employees .',
#    'tokens': ['in',
#     'general',
#     ',',
#     'to',
#     'be',
#     'qualified',
#     'under',
#     'the',
#     'irc',
#     ',',
#     'a',
#     'pension',
#     'plan',
#     'must',
#     'be',
#     'established',
#     'with',
#     'the',
#     'intent',
#     'of',
#     'being',
#     'a',
#     'permanent',
#     'and',
#     'continuing',
#     'arrangement',
#     ';',
#     'must',
#     'provide',
#     'definitely',
#     'determinable',
#     'benefits',
#     ';',
#     'may',
#     'not',
#     'discriminate',
#     'in',
#     'favor',
#     'of',
#     'highly',
#     'compensated',
#     'employees',
#     'with',
#     'respect',
#     'to',
#     'coverage',
#     ',',
#     'contributions',
#     ',',
#     'or',
#     'benefits',
#     ';',
#     'and',
#     'must',
#     'cover',
#     'a',
#     'minimum',
#     'number',
#     'or',
#     'percentage',
#     'of',
#     'employees',
#     '.'],
#    'sentence_id': 48,
#    'word_count': 63},
#   {'text': 'pension plans specifically excluded by law from being insured by pbgc include governmental plans , church plans , plans of fraternal societies financed entirely by member contributions , plans maintained by certain professionals ( such as physicians , attorneys , and artists ) with 25 or fewer participants , and plans established and maintained exclusively for substantial owners of businesses .',
#    'tokens': ['pension',
#     'plans',
#     'specifically',
#     'excluded',
#     'by',
#     'law',
#     'from',
#     'being',
#     'insured',
#     'by',
#     'pbgc',
#     'include',
#     'governmental',
#     'plans',
#     ',',
#     'church',
#     'plans',
#     ',',
#     'plans',
#     'of',
#     'fraternal',
#     'societies',
#     'financed',
#     'entirely',
#     'by',
#     'member',
#     'contributions',
#     ',',
#     'plans',
#     'maintained',
#     'by',
#     'certain',
#     'professionals',
#     '(',
#     'such',
#     'as',
#     'physicians',
#     ',',
#     'attorneys',
#     ',',
#     'and',
#     'artists',
#     ')',
#     'with',
#     '25',
#     'or',
#     'fewer',
#     'participants',
#     ',',
#     'and',
#     'plans',
#     'established',
#     'and',
#     'maintained',
#     'exclusively',
#     'for',
#     'substantial',
#     'owners',
#     'of',
#     'businesses',
#     '.'],
#    'sentence_id': 49,
#    'word_count': 61},
#   {'text': "pbgc's single - employer and multiemployer insurance programs operate differently and pbgc maintains separate reserve funds for each program .",
#    'tokens': ['pbgc',
#     "'s",
#     'single',
#     '-',
#     'employer',
#     'and',
#     'multiemployer',
#     'insurance',
#     'programs',
#     'operate',
#     'differently',
#     'and',
#     'pbgc',
#     'maintains',
#     'separate',
#     'reserve',
#     'funds',
#     'for',
#     'each',
#     'program',
#     '.'],
#    'sentence_id': 50,
#    'word_count': 21},
#   {'text': 'funds from the reserve of one program may not be used for the other program .',
#    'tokens': ['funds',
#     'from',
#     'the',
#     'reserve',
#     'of',
#     'one',
#     'program',
#     'may',
#     'not',
#     'be',
#     'used',
#     'for',
#     'the',
#     'other',
#     'program',
#     '.'],
#    'sentence_id': 51,
#    'word_count': 16},
#   {'text': 'in the single - employer program , pbgc becomes the trustee of the terminated , underfunded single - employer db pension plans .',
#    'tokens': ['in',
#     'the',
#     'single',
#     '-',
#     'employer',
#     'program',
#     ',',
#     'pbgc',
#     'becomes',
#     'the',
#     'trustee',
#     'of',
#     'the',
#     'terminated',
#     ',',
#     'underfunded',
#     'single',
#     '-',
#     'employer',
#     'db',
#     'pension',
#     'plans',
#     '.'],
#    'sentence_id': 52,
#    'word_count': 23},
#   {'text': 'the assets of the terminated plan are placed in a trust fund operated by pbgc .',
#    'tokens': ['the',
#     'assets',
#     'of',
#     'the',
#     'terminated',
#     'plan',
#     'are',
#     'placed',
#     'in',
#     'a',
#     'trust',
#     'fund',
#     'operated',
#     'by',
#     'pbgc',
#     '.'],
#    'sentence_id': 53,
#    'word_count': 16},
#   {'text': 'the participants in the trusteed plans receive their benefits from pbgc .',
#    'tokens': ['the',
#     'participants',
#     'in',
#     'the',
#     'trusteed',
#     'plans',
#     'receive',
#     'their',
#     'benefits',
#     'from',
#     'pbgc',
#     '.'],
#    'sentence_id': 54,
#    'word_count': 12},
#   {'text': 'in the multiemployer program , pbgc does not become the trustee of plans .',
#    'tokens': ['in',
#     'the',
#     'multiemployer',
#     'program',
#     ',',
#     'pbgc',
#     'does',
#     'not',
#     'become',
#     'the',
#     'trustee',
#     'of',
#     'plans',
#     '.'],
#    'sentence_id': 55,
#    'word_count': 14},
#   {'text': 'pbgc makes loans to multiemployer db pension plans when the plans become insolvent .',
#    'tokens': ['pbgc',
#     'makes',
#     'loans',
#     'to',
#     'multiemployer',
#     'db',
#     'pension',
#     'plans',
#     'when',
#     'the',
#     'plans',
#     'become',
#     'insolvent',
#     '.'],
#    'sentence_id': 56,
#    'word_count': 14},
#   {'text': 'an insolvent multiemployer plan has insufficient assets available from which to pay participant benefits .',
#    'tokens': ['an',
#     'insolvent',
#     'multiemployer',
#     'plan',
#     'has',
#     'insufficient',
#     'assets',
#     'available',
#     'from',
#     'which',
#     'to',
#     'pay',
#     'participant',
#     'benefits',
#     '.'],
#    'sentence_id': 57,
#    'word_count': 15},
#   {'text': 'an employer can voluntarily terminate a single - employer plan in either a standard or distress termination .',
#    'tokens': ['an',
#     'employer',
#     'can',
#     'voluntarily',
#     'terminate',
#     'a',
#     'single',
#     '-',
#     'employer',
#     'plan',
#     'in',
#     'either',
#     'a',
#     'standard',
#     'or',
#     'distress',
#     'termination',
#     '.'],
#    'sentence_id': 58,
#    'word_count': 18},
#   {'text': 'the participants and pbgc must be notified of the termination .',
#    'tokens': ['the',
#     'participants',
#     'and',
#     'pbgc',
#     'must',
#     'be',
#     'notified',
#     'of',
#     'the',
#     'termination',
#     '.'],
#    'sentence_id': 59,
#    'word_count': 11},
#   {'text': 'pbgc may involuntarily terminate an underfunded plan if the sponsor is unable to fund its pension obligations .',
#    'tokens': ['pbgc',
#     'may',
#     'involuntarily',
#     'terminate',
#     'an',
#     'underfunded',
#     'plan',
#     'if',
#     'the',
#     'sponsor',
#     'is',
#     'unable',
#     'to',
#     'fund',
#     'its',
#     'pension',
#     'obligations',
#     '.'],
#    'sentence_id': 60,
#    'word_count': 18},
#   {'text': "a company may voluntarily end its pension plan if the plan's assets are sufficient to cover benefit liabilities .",
#    'tokens': ['a',
#     'company',
#     'may',
#     'voluntarily',
#     'end',
#     'its',
#     'pension',
#     'plan',
#     'if',
#     'the',
#     'plan',
#     "'s",
#     'assets',
#     'are',
#     'sufficient',
#     'to',
#     'cover',
#     'benefit',
#     'liabilities',
#     '.'],
#    'sentence_id': 61,
#    'word_count': 20},
#   {'text': 'in such cases , pbgc does not pay any benefits to plan participants .',
#    'tokens': ['in',
#     'such',
#     'cases',
#     ',',
#     'pbgc',
#     'does',
#     'not',
#     'pay',
#     'any',
#     'benefits',
#     'to',
#     'plan',
#     'participants',
#     '.'],
#    'sentence_id': 62,
#    'word_count': 14},
#   {'text': 'its role is to confirm that the requirements for termination have been met by the plan .',
#    'tokens': ['its',
#     'role',
#     'is',
#     'to',
#     'confirm',
#     'that',
#     'the',
#     'requirements',
#     'for',
#     'termination',
#     'have',
#     'been',
#     'met',
#     'by',
#     'the',
#     'plan',
#     '.'],
#    'sentence_id': 63,
#    'word_count': 17},
#   {'text': 'generally , benefit liabilities equal all benefits earned to date by plan participants , including vested and nonvested benefits ( which automatically become vested at the time of termination ) , plus certain early retirement supplements and subsidies .',
#    'tokens': ['generally',
#     ',',
#     'benefit',
#     'liabilities',
#     'equal',
#     'all',
#     'benefits',
#     'earned',
#     'to',
#     'date',
#     'by',
#     'plan',
#     'participants',
#     ',',
#     'including',
#     'vested',
#     'and',
#     'nonvested',
#     'benefits',
#     '(',
#     'which',
#     'automatically',
#     'become',
#     'vested',
#     'at',
#     'the',
#     'time',
#     'of',
#     'termination',
#     ')',
#     ',',
#     'plus',
#     'certain',
#     'early',
#     'retirement',
#     'supplements',
#     'and',
#     'subsidies',
#     '.'],
#    'sentence_id': 64,
#    'word_count': 39},
#   {'text': 'benefit liabilities also may include certain contingent benefits .',
#    'tokens': ['benefit',
#     'liabilities',
#     'also',
#     'may',
#     'include',
#     'certain',
#     'contingent',
#     'benefits',
#     '.'],
#    'sentence_id': 65,
#    'word_count': 9},
#   {'text': 'if assets are sufficient to cover benefit liabilities ( and other termination requirements , such as notice to employees , have not been violated ) , the plan distributes benefits to participants .',
#    'tokens': ['if',
#     'assets',
#     'are',
#     'sufficient',
#     'to',
#     'cover',
#     'benefit',
#     'liabilities',
#     '(',
#     'and',
#     'other',
#     'termination',
#     'requirements',
#     ',',
#     'such',
#     'as',
#     'notice',
#     'to',
#     'employees',
#     ',',
#     'have',
#     'not',
#     'been',
#     'violated',
#     ')',
#     ',',
#     'the',
#     'plan',
#     'distributes',
#     'benefits',
#     'to',
#     'participants',
#     '.'],
#    'sentence_id': 66,
#    'word_count': 33},
#   {'text': 'the plan provides for the benefit payments it owes by purchasing annuity contracts from an insurance company , or otherwise providing for the payment of benefits , for example , by providing the benefits in lump - sum distributions .',
#    'tokens': ['the',
#     'plan',
#     'provides',
#     'for',
#     'the',
#     'benefit',
#     'payments',
#     'it',
#     'owes',
#     'by',
#     'purchasing',
#     'annuity',
#     'contracts',
#     'from',
#     'an',
#     'insurance',
#     'company',
#     ',',
#     'or',
#     'otherwise',
#     'providing',
#     'for',
#     'the',
#     'payment',
#     'of',
#     'benefits',
#     ',',
#     'for',
#     'example',
#     ',',
#     'by',
#     'providing',
#     'the',
#     'benefits',
#     'in',
#     'lump',
#     '-',
#     'sum',
#     'distributions',
#     '.'],
#    'sentence_id': 67,
#    'word_count': 40},
#   {'text': 'assets in excess of the amounts necessary to cover benefit liabilities may be recovered by the employer in an asset reversion .',
#    'tokens': ['assets',
#     'in',
#     'excess',
#     'of',
#     'the',
#     'amounts',
#     'necessary',
#     'to',
#     'cover',
#     'benefit',
#     'liabilities',
#     'may',
#     'be',
#     'recovered',
#     'by',
#     'the',
#     'employer',
#     'in',
#     'an',
#     'asset',
#     'reversion',
#     '.'],
#    'sentence_id': 68,
#    'word_count': 22},
#   {'text': "the asset reversion is included in the employer's gross income and is subject to a nondeductible excise tax .",
#    'tokens': ['the',
#     'asset',
#     'reversion',
#     'is',
#     'included',
#     'in',
#     'the',
#     'employer',
#     "'s",
#     'gross',
#     'income',
#     'and',
#     'is',
#     'subject',
#     'to',
#     'a',
#     'nondeductible',
#     'excise',
#     'tax',
#     '.'],
#    'sentence_id': 69,
#    'word_count': 20},
#   {'text': 'the excise tax is 20% of the amount of the reversion if the employer establishes a qualified replacement plan or provides certain benefit increases in connection with the termination .',
#    'tokens': ['the',
#     'excise',
#     'tax',
#     'is',
#     '20',
#     '%',
#     'of',
#     'the',
#     'amount',
#     'of',
#     'the',
#     'reversion',
#     'if',
#     'the',
#     'employer',
#     'establishes',
#     'a',
#     'qualified',
#     'replacement',
#     'plan',
#     'or',
#     'provides',
#     'certain',
#     'benefit',
#     'increases',
#     'in',
#     'connection',
#     'with',
#     'the',
#     'termination',
#     '.'],
#    'sentence_id': 70,
#    'word_count': 31},
#   {'text': 'otherwise , the excise tax is 50% of the reversion amount .',
#    'tokens': ['otherwise',
#     ',',
#     'the',
#     'excise',
#     'tax',
#     'is',
#     '50',
#     '%',
#     'of',
#     'the',
#     'reversion',
#     'amount',
#     '.'],
#    'sentence_id': 71,
#    'word_count': 13},
#   {'text': 'when an underfunded plan terminates in a distress or involuntary termination , the plan goes into pbgc receivership .',
#    'tokens': ['when',
#     'an',
#     'underfunded',
#     'plan',
#     'terminates',
#     'in',
#     'a',
#     'distress',
#     'or',
#     'involuntary',
#     'termination',
#     ',',
#     'the',
#     'plan',
#     'goes',
#     'into',
#     'pbgc',
#     'receivership',
#     '.'],
#    'sentence_id': 72,
#    'word_count': 19},
#   {'text': 'pbgc becomes the trustee of the plan , takes control of any plan assets , and assumes responsibility for liabilities under the plan .',
#    'tokens': ['pbgc',
#     'becomes',
#     'the',
#     'trustee',
#     'of',
#     'the',
#     'plan',
#     ',',
#     'takes',
#     'control',
#     'of',
#     'any',
#     'plan',
#     'assets',
#     ',',
#     'and',
#     'assumes',
#     'responsibility',
#     'for',
#     'liabilities',
#     'under',
#     'the',
#     'plan',
#     '.'],
#    'sentence_id': 73,
#    'word_count': 24},
#   {'text': 'pbgc makes payments for benefit liabilities promised under the plan with assets received from two sources: ( 1 ) assets in the plan before termination and ( 2 ) assets recovered from employers .',
#    'tokens': ['pbgc',
#     'makes',
#     'payments',
#     'for',
#     'benefit',
#     'liabilities',
#     'promised',
#     'under',
#     'the',
#     'plan',
#     'with',
#     'assets',
#     'received',
#     'from',
#     'two',
#     'sources',
#     ':',
#     '(',
#     '1',
#     ')',
#     'assets',
#     'in',
#     'the',
#     'plan',
#     'before',
#     'termination',
#     'and',
#     '(',
#     '2',
#     ')',
#     'assets',
#     'recovered',
#     'from',
#     'employers',
#     '.'],
#    'sentence_id': 74,
#    'word_count': 35},
#   {'text': "the balance , if any , of guaranteed benefits owed to beneficiaries is paid from pbgc's revolving funds .",
#    'tokens': ['the',
#     'balance',
#     ',',
#     'if',
#     'any',
#     ',',
#     'of',
#     'guaranteed',
#     'benefits',
#     'owed',
#     'to',
#     'beneficiaries',
#     'is',
#     'paid',
#     'from',
#     'pbgc',
#     "'s",
#     'revolving',
#     'funds',
#     '.'],
#    'sentence_id': 75,
#    'word_count': 20},
#   {'text': 'distress terminations if assets in the plan are not sufficient to cover benefit liabilities , the employer may not terminate the plan unless the employer meets one of four criteria necessary for a "distress" termination: 1 .',
#    'tokens': ['distress',
#     'terminations',
#     'if',
#     'assets',
#     'in',
#     'the',
#     'plan',
#     'are',
#     'not',
#     'sufficient',
#     'to',
#     'cover',
#     'benefit',
#     'liabilities',
#     ',',
#     'the',
#     'employer',
#     'may',
#     'not',
#     'terminate',
#     'the',
#     'plan',
#     'unless',
#     'the',
#     'employer',
#     'meets',
#     'one',
#     'of',
#     'four',
#     'criteria',
#     'necessary',
#     'for',
#     'a',
#     '``',
#     'distress',
#     "''",
#     'termination',
#     ':',
#     '1',
#     '.'],
#    'sentence_id': 76,
#    'word_count': 40},
#   {'text': 'the plan sponsor , and every member of the controlled group ( companies with the same ownership ) of which the sponsor is a member , has filed or had filed against it a petition seeking liquidation in bankruptcy or any similar federal law or other similar state insolvency proceedings ; 2 .',
#    'tokens': ['the',
#     'plan',
#     'sponsor',
#     ',',
#     'and',
#     'every',
#     'member',
#     'of',
#     'the',
#     'controlled',
#     'group',
#     '(',
#     'companies',
#     'with',
#     'the',
#     'same',
#     'ownership',
#     ')',
#     'of',
#     'which',
#     'the',
#     'sponsor',
#     'is',
#     'a',
#     'member',
#     ',',
#     'has',
#     'filed',
#     'or',
#     'had',
#     'filed',
#     'against',
#     'it',
#     'a',
#     'petition',
#     'seeking',
#     'liquidation',
#     'in',
#     'bankruptcy',
#     'or',
#     'any',
#     'similar',
#     'federal',
#     'law',
#     'or',
#     'other',
#     'similar',
#     'state',
#     'insolvency',
#     'proceedings',
#     ';',
#     '2',
#     '.'],
#    'sentence_id': 77,
#    'word_count': 53},
#   {'text': "the plan sponsor , and every member of the sponsor's controlled group , has filed or had filed against it a petition to reorganize in bankruptcy or similar state proceedings .",
#    'tokens': ['the',
#     'plan',
#     'sponsor',
#     ',',
#     'and',
#     'every',
#     'member',
#     'of',
#     'the',
#     'sponsor',
#     "'s",
#     'controlled',
#     'group',
#     ',',
#     'has',
#     'filed',
#     'or',
#     'had',
#     'filed',
#     'against',
#     'it',
#     'a',
#     'petition',
#     'to',
#     'reorganize',
#     'in',
#     'bankruptcy',
#     'or',
#     'similar',
#     'state',
#     'proceedings',
#     '.'],
#    'sentence_id': 78,
#    'word_count': 32},
#   {'text': 'this criterion is also met if the bankruptcy court ( or other appropriate court ) determines that , unless the plan is terminated , the employer will be unable to continue in business outside the reorganization process and approves the plan termination ; 3 .',
#    'tokens': ['this',
#     'criterion',
#     'is',
#     'also',
#     'met',
#     'if',
#     'the',
#     'bankruptcy',
#     'court',
#     '(',
#     'or',
#     'other',
#     'appropriate',
#     'court',
#     ')',
#     'determines',
#     'that',
#     ',',
#     'unless',
#     'the',
#     'plan',
#     'is',
#     'terminated',
#     ',',
#     'the',
#     'employer',
#     'will',
#     'be',
#     'unable',
#     'to',
#     'continue',
#     'in',
#     'business',
#     'outside',
#     'the',
#     'reorganization',
#     'process',
#     'and',
#     'approves',
#     'the',
#     'plan',
#     'termination',
#     ';',
#     '3',
#     '.'],
#    'sentence_id': 79,
#    'word_count': 45},
#   {'text': 'pbgc determines that termination is necessary to allow the employer to pay its debts when due ; or 4 .',
#    'tokens': ['pbgc',
#     'determines',
#     'that',
#     'termination',
#     'is',
#     'necessary',
#     'to',
#     'allow',
#     'the',
#     'employer',
#     'to',
#     'pay',
#     'its',
#     'debts',
#     'when',
#     'due',
#     ';',
#     'or',
#     '4',
#     '.'],
#    'sentence_id': 80,
#    'word_count': 20},
#   {'text': "pbgc determines that termination is necessary to avoid unreasonably burdensome pension costs caused solely by a decline in the employer's work force .",
#    'tokens': ['pbgc',
#     'determines',
#     'that',
#     'termination',
#     'is',
#     'necessary',
#     'to',
#     'avoid',
#     'unreasonably',
#     'burdensome',
#     'pension',
#     'costs',
#     'caused',
#     'solely',
#     'by',
#     'a',
#     'decline',
#     'in',
#     'the',
#     'employer',
#     "'s",
#     'work',
#     'force',
#     '.'],
#    'sentence_id': 81,
#    'word_count': 24},
#   {'text': 'these requirements were added by the single employer pension plan amendments act of 1986 ( seppaa ; p.l .',
#    'tokens': ['these',
#     'requirements',
#     'were',
#     'added',
#     'by',
#     'the',
#     'single',
#     'employer',
#     'pension',
#     'plan',
#     'amendments',
#     'act',
#     'of',
#     '1986',
#     '(',
#     'seppaa',
#     ';',
#     'p.l',
#     '.'],
#    'sentence_id': 82,
#    'word_count': 19},
#   {'text': '99-272 ) and modified by the omnibus budget reconciliation act of 1987 ( p.l .',
#    'tokens': ['99-272',
#     ')',
#     'and',
#     'modified',
#     'by',
#     'the',
#     'omnibus',
#     'budget',
#     'reconciliation',
#     'act',
#     'of',
#     '1987',
#     '(',
#     'p.l',
#     '.'],
#    'sentence_id': 83,
#    'word_count': 15},
#   {'text': '100-203 ) and the retirement protection act of 1994 ( rpa ; p.l .',
#    'tokens': ['100-203',
#     ')',
#     'and',
#     'the',
#     'retirement',
#     'protection',
#     'act',
#     'of',
#     '1994',
#     '(',
#     'rpa',
#     ';',
#     'p.l',
#     '.'],
#    'sentence_id': 84,
#    'word_count': 14},
#   {'text': '103-465 ) .',
#    'tokens': ['103-465', ')', '.'],
#    'sentence_id': 85,
#    'word_count': 3},
#   {'text': 'they are designed to ensure that the liabilities of an underfunded plan remain the responsibility of the employer , rather than pbgc , unless the employer meets strict standards of financial need indicating genuine inability to continue funding the plan .',
#    'tokens': ['they',
#     'are',
#     'designed',
#     'to',
#     'ensure',
#     'that',
#     'the',
#     'liabilities',
#     'of',
#     'an',
#     'underfunded',
#     'plan',
#     'remain',
#     'the',
#     'responsibility',
#     'of',
#     'the',
#     'employer',
#     ',',
#     'rather',
#     'than',
#     'pbgc',
#     ',',
#     'unless',
#     'the',
#     'employer',
#     'meets',
#     'strict',
#     'standards',
#     'of',
#     'financial',
#     'need',
#     'indicating',
#     'genuine',
#     'inability',
#     'to',
#     'continue',
#     'funding',
#     'the',
#     'plan',
#     '.'],
#    'sentence_id': 86,
#    'word_count': 41},
#   {'text': 'involuntary terminations pbgc may terminate a plan involuntarily , either by agreement with the plan sponsor or pursuant to a federal court order .',
#    'tokens': ['involuntary',
#     'terminations',
#     'pbgc',
#     'may',
#     'terminate',
#     'a',
#     'plan',
#     'involuntarily',
#     ',',
#     'either',
#     'by',
#     'agreement',
#     'with',
#     'the',
#     'plan',
#     'sponsor',
#     'or',
#     'pursuant',
#     'to',
#     'a',
#     'federal',
#     'court',
#     'order',
#     '.'],
#    'sentence_id': 87,
#    'word_count': 24},
#   {'text': 'pbgc may institute such proceedings only if the plan in question has not met the minimum funding standards , the plan will be unable to pay benefits when due , the plan has a substantial owner who has received a distribution greater than $10,000 ( other than by reason of death ) and the plan has unfunded vested benefits , or the long - run loss to pbgc with respect to the plan is expected to increase unreasonably if the plan is not terminated .',
#    'tokens': ['pbgc',
#     'may',
#     'institute',
#     'such',
#     'proceedings',
#     'only',
#     'if',
#     'the',
#     'plan',
#     'in',
#     'question',
#     'has',
#     'not',
#     'met',
#     'the',
#     'minimum',
#     'funding',
#     'standards',
#     ',',
#     'the',
#     'plan',
#     'will',
#     'be',
#     'unable',
#     'to',
#     'pay',
#     'benefits',
#     'when',
#     'due',
#     ',',
#     'the',
#     'plan',
#     'has',
#     'a',
#     'substantial',
#     'owner',
#     'who',
#     'has',
#     'received',
#     'a',
#     'distribution',
#     'greater',
#     'than',
#     '$',
#     '10,000',
#     '(',
#     'other',
#     'than',
#     'by',
#     'reason',
#     'of',
#     'death',
#     ')',
#     'and',
#     'the',
#     'plan',
#     'has',
#     'unfunded',
#     'vested',
#     'benefits',
#     ',',
#     'or',
#     'the',
#     'long',
#     '-',
#     'run',
#     'loss',
#     'to',
#     'pbgc',
#     'with',
#     'respect',
#     'to',
#     'the',
#     'plan',
#     'is',
#     'expected',
#     'to',
#     'increase',
#     'unreasonably',
#     'if',
#     'the',
#     'plan',
#     'is',
#     'not',
#     'terminated',
#     '.'],
#    'sentence_id': 88,
#    'word_count': 86},
#   {'text': 'pbgc must terminate a plan if the plan is unable to pay benefits that are currently due .',
#    'tokens': ['pbgc',
#     'must',
#     'terminate',
#     'a',
#     'plan',
#     'if',
#     'the',
#     'plan',
#     'is',
#     'unable',
#     'to',
#     'pay',
#     'benefits',
#     'that',
#     'are',
#     'currently',
#     'due',
#     '.'],
#    'sentence_id': 89,
#    'word_count': 18},
#   {'text': "a federal court may order termination of the plan to protect the interests of participants , to avoid unreasonable deterioration of the plan's financial condition , or to avoid an unreasonable increase in pbgc's liability under the plan .",
#    'tokens': ['a',
#     'federal',
#     'court',
#     'may',
#     'order',
#     'termination',
#     'of',
#     'the',
#     'plan',
#     'to',
#     'protect',
#     'the',
#     'interests',
#     'of',
#     'participants',
#     ',',
#     'to',
#     'avoid',
#     'unreasonable',
#     'deterioration',
#     'of',
#     'the',
#     'plan',
#     "'s",
#     'financial',
#     'condition',
#     ',',
#     'or',
#     'to',
#     'avoid',
#     'an',
#     'unreasonable',
#     'increase',
#     'in',
#     'pbgc',
#     "'s",
#     'liability',
#     'under',
#     'the',
#     'plan',
#     '.'],
#    'sentence_id': 90,
#    'word_count': 41},
#   {'text': 'table 2 provides information on the number of terminations since 1974 by single - employer db pension plans and the number of these terminations that resulted in pbgc becoming trustee of the pension plan .',
#    'tokens': ['table',
#     '2',
#     'provides',
#     'information',
#     'on',
#     'the',
#     'number',
#     'of',
#     'terminations',
#     'since',
#     '1974',
#     'by',
#     'single',
#     '-',
#     'employer',
#     'db',
#     'pension',
#     'plans',
#     'and',
#     'the',
#     'number',
#     'of',
#     'these',
#     'terminations',
#     'that',
#     'resulted',
#     'in',
#     'pbgc',
#     'becoming',
#     'trustee',
#     'of',
#     'the',
#     'pension',
#     'plan',
#     '.'],
#    'sentence_id': 91,
#    'word_count': 35},
#   {'text': 'from fy1974 through fy2016 , pbgc became the trustee of 4,769 single - employer db pension plans .',
#    'tokens': ['from',
#     'fy1974',
#     'through',
#     'fy2016',
#     ',',
#     'pbgc',
#     'became',
#     'the',
#     'trustee',
#     'of',
#     '4,769',
#     'single',
#     '-',
#     'employer',
#     'db',
#     'pension',
#     'plans',
#     '.'],
#    'sentence_id': 92,
#    'word_count': 18},
#   {'text': 'the number of single - employer plan terminations that result in claims against pbgc is a relatively small fraction of all plan terminations .',
#    'tokens': ['the',
#     'number',
#     'of',
#     'single',
#     '-',
#     'employer',
#     'plan',
#     'terminations',
#     'that',
#     'result',
#     'in',
#     'claims',
#     'against',
#     'pbgc',
#     'is',
#     'a',
#     'relatively',
#     'small',
#     'fraction',
#     'of',
#     'all',
#     'plan',
#     'terminations',
# ...
#    'tokens': ['each',
#     'year',
#     ',',
#     'pbgc',
#     'transfers',
#     'funds',
#     'from',
#     'the',
#     'trust',
#     'fund',
#     'to',
#     'the',
#     'revolving',
#     'funds',
#     'to',
#     'pay',
#     'for',
#     'a',
#     'share',
#     'of',
#     'participants',
#     "'",
#     'benefits',
#     '.'],
#    'sentence_id': 183,
#    'word_count': 24},
#   {'text': 'the investments of the revolving funds are , by law , invested exclusively in u.s. treasury securities .',
#    'tokens': ['the',
#     'investments',
#     'of',
#     'the',
#     'revolving',
#     'funds',
#     'are',
#     ',',
#     'by',
#     'law',
#     ',',
#     'invested',
#     'exclusively',
#     'in',
#     'u.s.',
#     'treasury',
#     'securities',
#     '.'],
#    'sentence_id': 184,
#    'word_count': 18},
#   {'text': "the revolving funds' assets at the end of fy2018 were $1.8 billion for fund 1 , $2.1 billion for fund 2 , and $29.3 billion for fund 7 , for a total of $33.2 billion .",
#    'tokens': ['the',
#     'revolving',
#     'funds',
#     "'",
#     'assets',
#     'at',
#     'the',
#     'end',
#     'of',
#     'fy2018',
#     'were',
#     '$',
#     '1.8',
#     'billion',
#     'for',
#     'fund',
#     '1',
#     ',',
#     '$',
#     '2.1',
#     'billion',
#     'for',
#     'fund',
#     '2',
#     ',',
#     'and',
#     '$',
#     '29.3',
#     'billion',
#     'for',
#     'fund',
#     '7',
#     ',',
#     'for',
#     'a',
#     'total',
#     'of',
#     '$',
#     '33.2',
#     'billion',
#     '.'],
#    'sentence_id': 185,
#    'word_count': 41},
#   {'text': 'the revolving funds are on - budget accounts: increases or decreases in the revolving funds appear as on - budget federal receipts and outlays .',
#    'tokens': ['the',
#     'revolving',
#     'funds',
#     'are',
#     'on',
#     '-',
#     'budget',
#     'accounts',
#     ':',
#     'increases',
#     'or',
#     'decreases',
#     'in',
#     'the',
#     'revolving',
#     'funds',
#     'appear',
#     'as',
#     'on',
#     '-',
#     'budget',
#     'federal',
#     'receipts',
#     'and',
#     'outlays',
#     '.'],
#    'sentence_id': 186,
#    'word_count': 26},
#   {'text': "the funds' gross outlays include pbgc benefit payments and administrative expenses and receipts include premiums paid , interest on federal securities , and reimbursements from the trust fund .",
#    'tokens': ['the',
#     'funds',
#     "'",
#     'gross',
#     'outlays',
#     'include',
#     'pbgc',
#     'benefit',
#     'payments',
#     'and',
#     'administrative',
#     'expenses',
#     'and',
#     'receipts',
#     'include',
#     'premiums',
#     'paid',
#     ',',
#     'interest',
#     'on',
#     'federal',
#     'securities',
#     ',',
#     'and',
#     'reimbursements',
#     'from',
#     'the',
#     'trust',
#     'fund',
#     '.'],
#    'sentence_id': 187,
#    'word_count': 30},
#   {'text': 'because increases in the premiums paid by pension plan sponsors to pbgc are increases in federal revenue , some stakeholders and policymakers have criticized recent pbgc premium increases because they feel increases in premiums are used to offset other federal spending , do not address the financial condition of pbgc , and may discourage employers from maintaining their db pension plans .',
#    'tokens': ['because',
#     'increases',
#     'in',
#     'the',
#     'premiums',
#     'paid',
#     'by',
#     'pension',
#     'plan',
#     'sponsors',
#     'to',
#     'pbgc',
#     'are',
#     'increases',
#     'in',
#     'federal',
#     'revenue',
#     ',',
#     'some',
#     'stakeholders',
#     'and',
#     'policymakers',
#     'have',
#     'criticized',
#     'recent',
#     'pbgc',
#     'premium',
#     'increases',
#     'because',
#     'they',
#     'feel',
#     'increases',
#     'in',
#     'premiums',
#     'are',
#     'used',
#     'to',
#     'offset',
#     'other',
#     'federal',
#     'spending',
#     ',',
#     'do',
#     'not',
#     'address',
#     'the',
#     'financial',
#     'condition',
#     'of',
#     'pbgc',
#     ',',
#     'and',
#     'may',
#     'discourage',
#     'employers',
#     'from',
#     'maintaining',
#     'their',
#     'db',
#     'pension',
#     'plans',
#     '.'],
#    'sentence_id': 188,
#    'word_count': 62},
#   {'text': 'in its fy2017 projections report , pbgc estimated its financial condition over the next 10 years .',
#    'tokens': ['in',
#     'its',
#     'fy2017',
#     'projections',
#     'report',
#     ',',
#     'pbgc',
#     'estimated',
#     'its',
#     'financial',
#     'condition',
#     'over',
#     'the',
#     'next',
#     '10',
#     'years',
#     '.'],
#    'sentence_id': 189,
#    'word_count': 17},
#   {'text': "the report indicated that the single - employer program's deficit is likely to shrink and the multiemployer program is likely to run out of money in fy2025 .",
#    'tokens': ['the',
#     'report',
#     'indicated',
#     'that',
#     'the',
#     'single',
#     '-',
#     'employer',
#     'program',
#     "'s",
#     'deficit',
#     'is',
#     'likely',
#     'to',
#     'shrink',
#     'and',
#     'the',
#     'multiemployer',
#     'program',
#     'is',
#     'likely',
#     'to',
#     'run',
#     'out',
#     'of',
#     'money',
#     'in',
#     'fy2025',
#     '.'],
#    'sentence_id': 190,
#    'word_count': 29},
#   {'text': 'pbgc projected that the single - employer program was likely to emerge from deficit by fy2018 ( which it did ) .',
#    'tokens': ['pbgc',
#     'projected',
#     'that',
#     'the',
#     'single',
#     '-',
#     'employer',
#     'program',
#     'was',
#     'likely',
#     'to',
#     'emerge',
#     'from',
#     'deficit',
#     'by',
#     'fy2018',
#     '(',
#     'which',
#     'it',
#     'did',
#     ')',
#     '.'],
#    'sentence_id': 191,
#    'word_count': 22},
#   {'text': "the average estimate of pbgc's simulations was a $26 billion surplus for the single - employer program in 10 years .",
#    'tokens': ['the',
#     'average',
#     'estimate',
#     'of',
#     'pbgc',
#     "'s",
#     'simulations',
#     'was',
#     'a',
#     '$',
#     '26',
#     'billion',
#     'surplus',
#     'for',
#     'the',
#     'single',
#     '-',
#     'employer',
#     'program',
#     'in',
#     '10',
#     'years',
#     '.'],
#    'sentence_id': 192,
#    'word_count': 23},
#   {'text': 'pbgc projected that there is a 90% chance that the multiemployer program will be insolvent before the end of fy2025 and a 99% chance that the multiemployer program will be insolvent by 2026 .',
#    'tokens': ['pbgc',
#     'projected',
#     'that',
#     'there',
#     'is',
#     'a',
#     '90',
#     '%',
#     'chance',
#     'that',
#     'the',
#     'multiemployer',
#     'program',
#     'will',
#     'be',
#     'insolvent',
#     'before',
#     'the',
#     'end',
#     'of',
#     'fy2025',
#     'and',
#     'a',
#     '99',
#     '%',
#     'chance',
#     'that',
#     'the',
#     'multiemployer',
#     'program',
#     'will',
#     'be',
#     'insolvent',
#     'by',
#     '2026',
#     '.'],
#    'sentence_id': 193,
#    'word_count': 36},
#   {'text': 'this is a result of the likely insolvency of several large multiemployer pension plans .',
#    'tokens': ['this',
#     'is',
#     'a',
#     'result',
#     'of',
#     'the',
#     'likely',
#     'insolvency',
#     'of',
#     'several',
#     'large',
#     'multiemployer',
#     'pension',
#     'plans',
#     '.'],
#    'sentence_id': 194,
#    'word_count': 15},
#   {'text': "pbgc's fy2018 annual report indicated that the multiemployer program's probable exposure to future financial assistance would be $53.8 billion .",
#    'tokens': ['pbgc',
#     "'s",
#     'fy2018',
#     'annual',
#     'report',
#     'indicated',
#     'that',
#     'the',
#     'multiemployer',
#     'program',
#     "'s",
#     'probable',
#     'exposure',
#     'to',
#     'future',
#     'financial',
#     'assistance',
#     'would',
#     'be',
#     '$',
#     '53.8',
#     'billion',
#     '.'],
#    'sentence_id': 195,
#    'word_count': 23},
#   {'text': 'premium levels are likely inadequate to provide continued financial assistance to insolvent multiemployer plans .',
#    'tokens': ['premium',
#     'levels',
#     'are',
#     'likely',
#     'inadequate',
#     'to',
#     'provide',
#     'continued',
#     'financial',
#     'assistance',
#     'to',
#     'insolvent',
#     'multiemployer',
#     'plans',
#     '.'],
#    'sentence_id': 196,
#    'word_count': 15},
#   {'text': "the financial assistance to these plans could exhaust pbgc's ability to guarantee participants' benefits .",
#    'tokens': ['the',
#     'financial',
#     'assistance',
#     'to',
#     'these',
#     'plans',
#     'could',
#     'exhaust',
#     'pbgc',
#     "'s",
#     'ability',
#     'to',
#     'guarantee',
#     'participants',
#     "'",
#     'benefits',
#     '.'],
#    'sentence_id': 197,
#    'word_count': 17},
#   {'text': "pbgc has indicated that once resources are exhausted in the pgbc's multiemployer program , insolvent plans would be required to reduce benefits to levels that could be sustained through premium collections only .",
#    'tokens': ['pbgc',
#     'has',
#     'indicated',
#     'that',
#     'once',
#     'resources',
#     'are',
#     'exhausted',
#     'in',
#     'the',
#     'pgbc',
#     "'s",
#     'multiemployer',
#     'program',
#     ',',
#     'insolvent',
#     'plans',
#     'would',
#     'be',
#     'required',
#     'to',
#     'reduce',
#     'benefits',
#     'to',
#     'levels',
#     'that',
#     'could',
#     'be',
#     'sustained',
#     'through',
#     'premium',
#     'collections',
#     'only',
#     '.'],
#    'sentence_id': 198,
#    'word_count': 34},
#   {'text': 'the multiemployer pension reform act of 2014 ( mpra , enacted as part of p.l .',
#    'tokens': ['the',
#     'multiemployer',
#     'pension',
#     'reform',
#     'act',
#     'of',
#     '2014',
#     '(',
#     'mpra',
#     ',',
#     'enacted',
#     'as',
#     'part',
#     'of',
#     'p.l',
#     '.'],
#    'sentence_id': 199,
#    'word_count': 16},
#   {'text': '113-235 ) , allowed , among other provisions , multiemployer db pension plans that expect to become insolvent to reduce benefits to participants in these plans .',
#    'tokens': ['113-235',
#     ')',
#     ',',
#     'allowed',
#     ',',
#     'among',
#     'other',
#     'provisions',
#     ',',
#     'multiemployer',
#     'db',
#     'pension',
#     'plans',
#     'that',
#     'expect',
#     'to',
#     'become',
#     'insolvent',
#     'to',
#     'reduce',
#     'benefits',
#     'to',
#     'participants',
#     'in',
#     'these',
#     'plans',
#     '.'],
#    'sentence_id': 200,
#    'word_count': 27},
#   {'text': 'an insolvent plan has no assets from which to pay any benefits .',
#    'tokens': ['an',
#     'insolvent',
#     'plan',
#     'has',
#     'no',
#     'assets',
#     'from',
#     'which',
#     'to',
#     'pay',
#     'any',
#     'benefits',
#     '.'],
#    'sentence_id': 201,
#    'word_count': 13},
#   {'text': 'plans that reduce benefits to forestall insolvency would not require financial assistance from pbgc , and would reduce the amount of future financial assistance pbgc would expect to provide .',
#    'tokens': ['plans',
#     'that',
#     'reduce',
#     'benefits',
#     'to',
#     'forestall',
#     'insolvency',
#     'would',
#     'not',
#     'require',
#     'financial',
#     'assistance',
#     'from',
#     'pbgc',
#     ',',
#     'and',
#     'would',
#     'reduce',
#     'the',
#     'amount',
#     'of',
#     'future',
#     'financial',
#     'assistance',
#     'pbgc',
#     'would',
#     'expect',
#     'to',
#     'provide',
#     '.'],
#    'sentence_id': 202,
#    'word_count': 30},
#   {'text': "this would likely improve pbgc's financial condition .",
#    'tokens': ['this',
#     'would',
#     'likely',
#     'improve',
#     'pbgc',
#     "'s",
#     'financial',
#     'condition',
#     '.'],
#    'sentence_id': 203,
#    'word_count': 9},
#   {'text': 'pbgc indicated that there is uncertainty in how the provisions of mpra that allow benefit suspensions and plan partitions will be used .',
#    'tokens': ['pbgc',
#     'indicated',
#     'that',
#     'there',
#     'is',
#     'uncertainty',
#     'in',
#     'how',
#     'the',
#     'provisions',
#     'of',
#     'mpra',
#     'that',
#     'allow',
#     'benefit',
#     'suspensions',
#     'and',
#     'plan',
#     'partitions',
#     'will',
#     'be',
#     'used',
#     '.'],
#    'sentence_id': 204,
#    'word_count': 23},
#   {'text': 'pbgc estimated that the effect of mpra would likely not change pbgc projections of future solvency .',
#    'tokens': ['pbgc',
#     'estimated',
#     'that',
#     'the',
#     'effect',
#     'of',
#     'mpra',
#     'would',
#     'likely',
#     'not',
#     'change',
#     'pbgc',
#     'projections',
#     'of',
#     'future',
#     'solvency',
#     '.'],
#    'sentence_id': 205,
#    'word_count': 17},
#   {'text': 'in response to the increasing concerns of policymakers and stakeholders ( such as participants , participating employers , and plans ) , the bipartisan budget act of 2018 ( p.l .',
#    'tokens': ['in',
#     'response',
#     'to',
#     'the',
#     'increasing',
#     'concerns',
#     'of',
#     'policymakers',
#     'and',
#     'stakeholders',
#     '(',
#     'such',
#     'as',
#     'participants',
#     ',',
#     'participating',
#     'employers',
#     ',',
#     'and',
#     'plans',
#     ')',
#     ',',
#     'the',
#     'bipartisan',
#     'budget',
#     'act',
#     'of',
#     '2018',
#     '(',
#     'p.l',
#     '.'],
#    'sentence_id': 206,
#    'word_count': 31},
#   {'text': '115-123 ) created a new joint select committee of the house and senate: the joint select committee on solvency of multiemployer pension plans .',
#    'tokens': ['115-123',
#     ')',
#     'created',
#     'a',
#     'new',
#     'joint',
#     'select',
#     'committee',
#     'of',
#     'the',
#     'house',
#     'and',
#     'senate',
#     ':',
#     'the',
#     'joint',
#     'select',
#     'committee',
#     'on',
#     'solvency',
#     'of',
#     'multiemployer',
#     'pension',
#     'plans',
#     '.'],
#    'sentence_id': 207,
#    'word_count': 25},
#   {'text': 'the committee was tasked with formulating recommendations and legislative language by november 30 , 2018 , that would "significantly improve the solvency of multiemployer pension plans and the pension benefit guaranty corporation. .',
#    'tokens': ['the',
#     'committee',
#     'was',
#     'tasked',
#     'with',
#     'formulating',
#     'recommendations',
#     'and',
#     'legislative',
#     'language',
#     'by',
#     'november',
#     '30',
#     ',',
#     '2018',
#     ',',
#     'that',
#     'would',
#     '``',
#     'significantly',
#     'improve',
#     'the',
#     'solvency',
#     'of',
#     'multiemployer',
#     'pension',
#     'plans',
#     'and',
#     'the',
#     'pension',
#     'benefit',
#     'guaranty',
#     'corporation',
#     '.',
#     '.'],
#    'sentence_id': 208,
#    'word_count': 35},
#   {'text': 'the committee did not release a report containing recommendations or legislative language by the deadline .',
#    'tokens': ['the',
#     'committee',
#     'did',
#     'not',
#     'release',
#     'a',
#     'report',
#     'containing',
#     'recommendations',
#     'or',
#     'legislative',
#     'language',
#     'by',
#     'the',
#     'deadline',
#     '.'],
#    'sentence_id': 209,
#    'word_count': 16},
#   {'text': ' table a - 1 provides historical data on the single - employer program premium levels .',
#    'tokens': ['table',
#     'a',
#     '-',
#     '1',
#     'provides',
#     'historical',
#     'data',
#     'on',
#     'the',
#     'single',
#     '-',
#     'employer',
#     'program',
#     'premium',
#     'levels',
#     '.'],
#    'sentence_id': 210,
#    'word_count': 16},
#   {'text': 'table a - 2 provides historical data on the multiemployer program premium levels .',
#    'tokens': ['table',
#     'a',
#     '-',
#     '2',
#     'provides',
#     'historical',
#     'data',
#     'on',
#     'the',
#     'multiemployer',
#     'program',
#     'premium',
#     'levels',
#     '.'],
#    'sentence_id': 211,
#    'word_count': 14}],
#  'section_names': ['',
#   'pension benefit guaranty corporation',
#   'pbgc administration',
#   'pbgc financing',
#   'premiums',
#   'requirements for pbgc coverage',
#   'pension benefit guaranty',
#   'single-employer insurance program',
#   'standard terminations',
#   'pbgc trusteeship',
#   'employer liability to pbgc',
#   'benefit payments',
#   'multiemployer pension insurance program',
#   'benefits for participants in multiemployer pension plans',
#   'current financial status',
#   'benefit payments in the single-employer insurance program',
#   'finances of the single-employer insurance program',
#   'finances of the multiemployer insurance program',
#   'pbgc and the federal budget',
#   'pbgc trust fund',
#   'pbgc revolving funds',
#   'future financial condition',
#   'appendix. historical pbgc premium rates'],
#  'section_lengths': [0,
#   16,
#   9,
#   6,
#   11,
#   7,
#   8,
#   3,
#   11,
#   23,
#   7,
#   25,
#   7,
#   9,
#   14,
#   4,
#   5,
#   7,
#   3,
#   5,
#   8,
#   21,
#   2]}

# %%
test = '3 - fold'
re.sub(r'([0-9]) - ', r'\1-', test)
# Out:
# '3-fold'

# %% [markdown]
# ### For all CRS files

# %%
path_to_json = 'gov-report/crs'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]

# %%
pbar = ProgressBar()
for d in pbar(json_files): 
    
    path = path_to_json + '/' + d
    f = open(path)
    file = json.load(f)
    f.close()
    
    out = finalFormatting(file, sectionInfo(file)[0], sectionInfo(file)[1], sectionInfo(file)[2])
    
    out_path = 'formatted-data/crs/' + d
    with open(out_path, 'w') as f:
        json.dump(out, f)
# Out:
# 100% |########################################################################|

# %% [markdown]
# ## GAO Files

# %% [markdown]
# Slightly different dictionary schema, so modify function

# %%
def sectionInfo(file): 
    
    # initialize vectors that will later be part of formatted file
    section_names = []
    section_lengths = []
    content = []
    
    
    for r in file['report']: 
        section_names.append(r['section_title'].lower())
        section_lengths.append(flattenParagraph(r['paragraphs'])[1])
        content = content + flattenParagraph(r['paragraphs'])[0]

        if r['subsections'] != []: 
            for s in r['subsections']: 
                section_names.append(s['section_title'].lower())
                section_lengths.append(flattenParagraph(s['paragraphs'])[1])
                content = content + flattenParagraph(s['paragraphs'])[0]

                if s['subsections'] != []: 
                    for t in s['subsections']: 
                        section_names.append(t['section_title'].lower())
                        section_lengths.append(flattenParagraph(t['paragraphs'])[1])
                        content = content + flattenParagraph(t['paragraphs'])[0]  

                        if t['subsections'] != []: 
                            for n in t['subsections']: 
                                section_names.append(n['section_title'].lower())
                                section_lengths.append(flattenParagraph(n['paragraphs'])[1])
                                content = content + flattenParagraph(n['paragraphs'])[0]  
                            
    return(section_names, section_lengths, content)

# %% [markdown]
# Example instance

# %%
f = open('gov-report/gao/AIMD-00-91.json',)
example = json.load(f)
f.close()

# %%
finalFormatting(example, sectionInfo(example)[0], sectionInfo(example)[1], sectionInfo(example)[2])
# Out:
# {'id': 'AIMD-00-91',
#  'inputs': [{'text': 'i am pleased to be here today to discuss the status of the 2000 census .',
#    'tokens': ['i',
#     'am',
#     'pleased',
#     'to',
#     'be',
#     'here',
#     'today',
#     'to',
#     'discuss',
#     'the',
#     'status',
#     'of',
#     'the',
#     '2000',
#     'census',
#     '.'],
#    'sentence_id': 1,
#    'word_count': 16},
#   {'text': "with just over 6 weeks remaining until census day , april 1 , 2000 , the decade - long process of researching , planning , testing , and evaluating procedures for the nation's largest peace - time mobilization has come to a close , and the complex and costly data collection and tabulation phase is now under way .",
#    'tokens': ['with',
#     'just',
#     'over',
#     '6',
#     'weeks',
#     'remaining',
#     'until',
#     'census',
#     'day',
#     ',',
#     'april',
#     '1',
#     ',',
#     '2000',
#     ',',
#     'the',
#     'decade',
#     '-',
#     'long',
#     'process',
#     'of',
#     'researching',
#     ',',
#     'planning',
#     ',',
#     'testing',
#     ',',
#     'and',
#     'evaluating',
#     'procedures',
#     'for',
#     'the',
#     'nation',
#     "'s",
#     'largest',
#     'peace',
#     '-',
#     'time',
#     'mobilization',
#     'has',
#     'come',
#     'to',
#     'a',
#     'close',
#     ',',
#     'and',
#     'the',
#     'complex',
#     'and',
#     'costly',
#     'data',
#     'collection',
#     'and',
#     'tabulation',
#     'phase',
#     'is',
#     'now',
#     'under',
#     'way',
#     '.'],
#    'sentence_id': 2,
#    'word_count': 60},
#   {'text': 'at this critical juncture , it is important to examine the state of the census , taking measure of the progress that has been made toward ensuring a complete and accurate enumeration , and the level of risk that remains .',
#    'tokens': ['at',
#     'this',
#     'critical',
#     'juncture',
#     ',',
#     'it',
#     'is',
#     'important',
#     'to',
#     'examine',
#     'the',
#     'state',
#     'of',
#     'the',
#     'census',
#     ',',
#     'taking',
#     'measure',
#     'of',
#     'the',
#     'progress',
#     'that',
#     'has',
#     'been',
#     'made',
#     'toward',
#     'ensuring',
#     'a',
#     'complete',
#     'and',
#     'accurate',
#     'enumeration',
#     ',',
#     'and',
#     'the',
#     'level',
#     'of',
#     'risk',
#     'that',
#     'remains',
#     '.'],
#    'sentence_id': 3,
#    'word_count': 41},
#   {'text': 'as you are aware , in two recent reports we discussed specific operational uncertainties that pose a threat to a successful population count .',
#    'tokens': ['as',
#     'you',
#     'are',
#     'aware',
#     ',',
#     'in',
#     'two',
#     'recent',
#     'reports',
#     'we',
#     'discussed',
#     'specific',
#     'operational',
#     'uncertainties',
#     'that',
#     'pose',
#     'a',
#     'threat',
#     'to',
#     'a',
#     'successful',
#     'population',
#     'count',
#     '.'],
#    'sentence_id': 4,
#    'word_count': 24},
#   {'text': 'in our december 1999 report , we concluded that the 2000 census may be less accurate than the 1990 census , in part because motivating public participation in the census will be a formidable task and field follow - up efforts with nonrespondents will be costly and may produce unreliable data .',
#    'tokens': ['in',
#     'our',
#     'december',
#     '1999',
#     'report',
#     ',',
#     'we',
#     'concluded',
#     'that',
#     'the',
#     '2000',
#     'census',
#     'may',
#     'be',
#     'less',
#     'accurate',
#     'than',
#     'the',
#     '1990',
#     'census',
#     ',',
#     'in',
#     'part',
#     'because',
#     'motivating',
#     'public',
#     'participation',
#     'in',
#     'the',
#     'census',
#     'will',
#     'be',
#     'a',
#     'formidable',
#     'task',
#     'and',
#     'field',
#     'follow',
#     '-',
#     'up',
#     'efforts',
#     'with',
#     'nonrespondents',
#     'will',
#     'be',
#     'costly',
#     'and',
#     'may',
#     'produce',
#     'unreliable',
#     'data',
#     '.'],
#    'sentence_id': 5,
#    'word_count': 52},
#   {'text': 'to address these uncertainties , we recommended that the director , bureau of the census , develop a contingency plan to mitigate the impact of a lower - than - expected mail response rate .',
#    'tokens': ['to',
#     'address',
#     'these',
#     'uncertainties',
#     ',',
#     'we',
#     'recommended',
#     'that',
#     'the',
#     'director',
#     ',',
#     'bureau',
#     'of',
#     'the',
#     'census',
#     ',',
#     'develop',
#     'a',
#     'contingency',
#     'plan',
#     'to',
#     'mitigate',
#     'the',
#     'impact',
#     'of',
#     'a',
#     'lower',
#     '-',
#     'than',
#     '-',
#     'expected',
#     'mail',
#     'response',
#     'rate',
#     '.'],
#    'sentence_id': 6,
#    'word_count': 35},
#   {'text': "moreover , in early - february , we reported on the challenges facing the bureau's data capture system .",
#    'tokens': ['moreover',
#     ',',
#     'in',
#     'early',
#     '-',
#     'february',
#     ',',
#     'we',
#     'reported',
#     'on',
#     'the',
#     'challenges',
#     'facing',
#     'the',
#     'bureau',
#     "'s",
#     'data',
#     'capture',
#     'system',
#     '.'],
#    'sentence_id': 7,
#    'word_count': 20},
#   {'text': "my statement today elaborates on the operational uncertainties addressed in these reports: ( 1 ) achieving the bureau's mail response rate objective , ( 2 ) collecting accurate and timely data from nonrespondents , and ( 3 ) conducting data capture operations .",
#    'tokens': ['my',
#     'statement',
#     'today',
#     'elaborates',
#     'on',
#     'the',
#     'operational',
#     'uncertainties',
#     'addressed',
#     'in',
#     'these',
#     'reports',
#     ':',
#     '(',
#     '1',
#     ')',
#     'achieving',
#     'the',
#     'bureau',
#     "'s",
#     'mail',
#     'response',
#     'rate',
#     'objective',
#     ',',
#     '(',
#     '2',
#     ')',
#     'collecting',
#     'accurate',
#     'and',
#     'timely',
#     'data',
#     'from',
#     'nonrespondents',
#     ',',
#     'and',
#     '(',
#     '3',
#     ')',
#     'conducting',
#     'data',
#     'capture',
#     'operations',
#     '.'],
#    'sentence_id': 8,
#    'word_count': 45},
#   {'text': "where appropriate , i've included information on developments that have occurred since these reports were issued that might affect the conduct of the census .",
#    'tokens': ['where',
#     'appropriate',
#     ',',
#     'i',
#     "'ve",
#     'included',
#     'information',
#     'on',
#     'developments',
#     'that',
#     'have',
#     'occurred',
#     'since',
#     'these',
#     'reports',
#     'were',
#     'issued',
#     'that',
#     'might',
#     'affect',
#     'the',
#     'conduct',
#     'of',
#     'the',
#     'census',
#     '.'],
#    'sentence_id': 9,
#    'word_count': 26},
#   {'text': "bureau's preparations for 2000 — including the 1998 dress rehearsal census — suggest that public and institutional cooperation will be inconsistent , and that pockets of problems are likely to occur that may not be captured by examining the census from a national perspective .",
#    'tokens': ['bureau',
#     "'s",
#     'preparations',
#     'for',
#     '2000',
#     '—',
#     'including',
#     'the',
#     '1998',
#     'dress',
#     'rehearsal',
#     'census',
#     '—',
#     'suggest',
#     'that',
#     'public',
#     'and',
#     'institutional',
#     'cooperation',
#     'will',
#     'be',
#     'inconsistent',
#     ',',
#     'and',
#     'that',
#     'pockets',
#     'of',
#     'problems',
#     'are',
#     'likely',
#     'to',
#     'occur',
#     'that',
#     'may',
#     'not',
#     'be',
#     'captured',
#     'by',
#     'examining',
#     'the',
#     'census',
#     'from',
#     'a',
#     'national',
#     'perspective',
#     '.'],
#    'sentence_id': 10,
#    'word_count': 46},
#   {'text': 'second , many of the risks to a complete and accurate census the bureau faces are interrelated .',
#    'tokens': ['second',
#     ',',
#     'many',
#     'of',
#     'the',
#     'risks',
#     'to',
#     'a',
#     'complete',
#     'and',
#     'accurate',
#     'census',
#     'the',
#     'bureau',
#     'faces',
#     'are',
#     'interrelated',
#     '.'],
#    'sentence_id': 11,
#    'word_count': 18},
#   {'text': 'mail response rates determine follow - up workload .',
#    'tokens': ['mail',
#     'response',
#     'rates',
#     'determine',
#     'follow',
#     '-',
#     'up',
#     'workload',
#     '.'],
#    'sentence_id': 12,
#    'word_count': 9},
#   {'text': "follow - up workload drives staffing needs , which in turn can affect the bureau's operational schedule and the quality of data .",
#    'tokens': ['follow',
#     '-',
#     'up',
#     'workload',
#     'drives',
#     'staffing',
#     'needs',
#     ',',
#     'which',
#     'in',
#     'turn',
#     'can',
#     'affect',
#     'the',
#     'bureau',
#     "'s",
#     'operational',
#     'schedule',
#     'and',
#     'the',
#     'quality',
#     'of',
#     'data',
#     '.'],
#    'sentence_id': 13,
#    'word_count': 24},
#   {'text': 'the cumulative and interrelated effect of these challenges is the fundamental risk facing the bureau .',
#    'tokens': ['the',
#     'cumulative',
#     'and',
#     'interrelated',
#     'effect',
#     'of',
#     'these',
#     'challenges',
#     'is',
#     'the',
#     'fundamental',
#     'risk',
#     'facing',
#     'the',
#     'bureau',
#     '.'],
#    'sentence_id': 14,
#    'word_count': 16},
#   {'text': 'third , the census is a shared national undertaking .',
#    'tokens': ['third',
#     ',',
#     'the',
#     'census',
#     'is',
#     'a',
#     'shared',
#     'national',
#     'undertaking',
#     '.'],
#    'sentence_id': 15,
#    'word_count': 10},
#   {'text': 'the bureau of the census , other federal agencies , state and local governments , a vast network of public and private organizations , and ultimately the american public , all play vital roles in making the census a success .',
#    'tokens': ['the',
#     'bureau',
#     'of',
#     'the',
#     'census',
#     ',',
#     'other',
#     'federal',
#     'agencies',
#     ',',
#     'state',
#     'and',
#     'local',
#     'governments',
#     ',',
#     'a',
#     'vast',
#     'network',
#     'of',
#     'public',
#     'and',
#     'private',
#     'organizations',
#     ',',
#     'and',
#     'ultimately',
#     'the',
#     'american',
#     'public',
#     ',',
#     'all',
#     'play',
#     'vital',
#     'roles',
#     'in',
#     'making',
#     'the',
#     'census',
#     'a',
#     'success',
#     '.'],
#    'sentence_id': 16,
#    'word_count': 41},
#   {'text': "we have been tracking the bureau's progress in designing and implementing the 2000 census throughout this past decade .",
#    'tokens': ['we',
#     'have',
#     'been',
#     'tracking',
#     'the',
#     'bureau',
#     "'s",
#     'progress',
#     'in',
#     'designing',
#     'and',
#     'implementing',
#     'the',
#     '2000',
#     'census',
#     'throughout',
#     'this',
#     'past',
#     'decade',
#     '.'],
#    'sentence_id': 17,
#    'word_count': 20},
#   {'text': "a consistent theme of our work has been that despite the bureau's unprecedented efforts to achieve maximum accuracy in the most cost - effective way possible , formidable challenges surround such key census - taking operations as building a complete and accurate address list , securing an acceptable level of public participation , hiring a sufficient number of temporary workers , and gathering accurate and complete data .",
#    'tokens': ['a',
#     'consistent',
#     'theme',
#     'of',
#     'our',
#     'work',
#     'has',
#     'been',
#     'that',
#     'despite',
#     'the',
#     'bureau',
#     "'s",
#     'unprecedented',
#     'efforts',
#     'to',
#     'achieve',
#     'maximum',
#     'accuracy',
#     'in',
#     'the',
#     'most',
#     'cost',
#     '-',
#     'effective',
#     'way',
#     'possible',
#     ',',
#     'formidable',
#     'challenges',
#     'surround',
#     'such',
#     'key',
#     'census',
#     '-',
#     'taking',
#     'operations',
#     'as',
#     'building',
#     'a',
#     'complete',
#     'and',
#     'accurate',
#     'address',
#     'list',
#     ',',
#     'securing',
#     'an',
#     'acceptable',
#     'level',
#     'of',
#     'public',
#     'participation',
#     ',',
#     'hiring',
#     'a',
#     'sufficient',
#     'number',
#     'of',
#     'temporary',
#     'workers',
#     ',',
#     'and',
#     'gathering',
#     'accurate',
#     'and',
#     'complete',
#     'data',
#     '.'],
#    'sentence_id': 18,
#    'word_count': 69},
#   {'text': 'these challenges have raised concerns that the 2000 census may be less accurate than the 1990 census .',
#    'tokens': ['these',
#     'challenges',
#     'have',
#     'raised',
#     'concerns',
#     'that',
#     'the',
#     '2000',
#     'census',
#     'may',
#     'be',
#     'less',
#     'accurate',
#     'than',
#     'the',
#     '1990',
#     'census',
#     '.'],
#    'sentence_id': 19,
#    'word_count': 18},
#   {'text': 'the cost of the 2000 census has already far surpassed that of the 1990 census in real terms .',
#    'tokens': ['the',
#     'cost',
#     'of',
#     'the',
#     '2000',
#     'census',
#     'has',
#     'already',
#     'far',
#     'surpassed',
#     'that',
#     'of',
#     'the',
#     '1990',
#     'census',
#     'in',
#     'real',
#     'terms',
#     '.'],
#    'sentence_id': 20,
#    'word_count': 19},
#   {'text': 'the bureau estimates that the 2000 census will cost at least $6.8 billion , which is more than double the $3.2 billion cost of the 1990 census in 1999 dollars .',
#    'tokens': ['the',
#     'bureau',
#     'estimates',
#     'that',
#     'the',
#     '2000',
#     'census',
#     'will',
#     'cost',
#     'at',
#     'least',
#     '$',
#     '6.8',
#     'billion',
#     ',',
#     'which',
#     'is',
#     'more',
#     'than',
#     'double',
#     'the',
#     '$',
#     '3.2',
#     'billion',
#     'cost',
#     'of',
#     'the',
#     '1990',
#     'census',
#     'in',
#     '1999',
#     'dollars',
#     '.'],
#    'sentence_id': 21,
#    'word_count': 33},
#   {'text': "to be sure , the nation's population — and thus the bureau's workload — has also increased over the past 10 years , but even when measured on a per housing unit basis , the price tag for enumerating each household has risen dramatically .",
#    'tokens': ['to',
#     'be',
#     'sure',
#     ',',
#     'the',
#     'nation',
#     "'s",
#     'population',
#     '—',
#     'and',
#     'thus',
#     'the',
#     'bureau',
#     "'s",
#     'workload',
#     '—',
#     'has',
#     'also',
#     'increased',
#     'over',
#     'the',
#     'past',
#     '10',
#     'years',
#     ',',
#     'but',
#     'even',
#     'when',
#     'measured',
#     'on',
#     'a',
#     'per',
#     'housing',
#     'unit',
#     'basis',
#     ',',
#     'the',
#     'price',
#     'tag',
#     'for',
#     'enumerating',
#     'each',
#     'household',
#     'has',
#     'risen',
#     'dramatically',
#     '.'],
#    'sentence_id': 22,
#    'word_count': 47},
#   {'text': 'it will cost an estimated $57 to enumerate each housing unit in 2000 compared to about $31 in 1990 , an increase of 84 percent in 1999 dollars .',
#    'tokens': ['it',
#     'will',
#     'cost',
#     'an',
#     'estimated',
#     '$',
#     '57',
#     'to',
#     'enumerate',
#     'each',
#     'housing',
#     'unit',
#     'in',
#     '2000',
#     'compared',
#     'to',
#     'about',
#     '$',
#     '31',
#     'in',
#     '1990',
#     ',',
#     'an',
#     'increase',
#     'of',
#     '84',
#     'percent',
#     'in',
#     '1999',
#     'dollars',
#     '.'],
#    'sentence_id': 23,
#    'word_count': 31},
#   {'text': "the scale and complexity of the bureau's task is enormous .",
#    'tokens': ['the',
#     'scale',
#     'and',
#     'complexity',
#     'of',
#     'the',
#     'bureau',
#     "'s",
#     'task',
#     'is',
#     'enormous',
#     '.'],
#    'sentence_id': 24,
#    'word_count': 12},
#   {'text': 'for the 2000 census , the bureau will need to properly locate and collect information from about 274 million people residing in over 119 million housing units .',
#    'tokens': ['for',
#     'the',
#     '2000',
#     'census',
#     ',',
#     'the',
#     'bureau',
#     'will',
#     'need',
#     'to',
#     'properly',
#     'locate',
#     'and',
#     'collect',
#     'information',
#     'from',
#     'about',
#     '274',
#     'million',
#     'people',
#     'residing',
#     'in',
#     'over',
#     '119',
#     'million',
#     'housing',
#     'units',
#     '.'],
#    'sentence_id': 25,
#    'word_count': 28},
#   {'text': 'to do this , the bureau opened 520 local census offices , and has plans to fill about 1.35 million temporary positions and process about 1.5 billion pages of data .',
#    'tokens': ['to',
#     'do',
#     'this',
#     ',',
#     'the',
#     'bureau',
#     'opened',
#     '520',
#     'local',
#     'census',
#     'offices',
#     ',',
#     'and',
#     'has',
#     'plans',
#     'to',
#     'fill',
#     'about',
#     '1.35',
#     'million',
#     'temporary',
#     'positions',
#     'and',
#     'process',
#     'about',
#     '1.5',
#     'billion',
#     'pages',
#     'of',
#     'data',
#     '.'],
#    'sentence_id': 26,
#    'word_count': 31},
#   {'text': 'for the 2000 census , the bureau will be challenged to boost the declining level of public participation in the census and collect timely and accurate data from initial nonrespondents .',
#    'tokens': ['for',
#     'the',
#     '2000',
#     'census',
#     ',',
#     'the',
#     'bureau',
#     'will',
#     'be',
#     'challenged',
#     'to',
#     'boost',
#     'the',
#     'declining',
#     'level',
#     'of',
#     'public',
#     'participation',
#     'in',
#     'the',
#     'census',
#     'and',
#     'collect',
#     'timely',
#     'and',
#     'accurate',
#     'data',
#     'from',
#     'initial',
#     'nonrespondents',
#     '.'],
#    'sentence_id': 27,
#    'word_count': 31},
#   {'text': 'a high mail response rate is key to a successful census because it helps the bureau obtain more accurate data and reduce what has been an error - prone and costly nonresponse follow - up workload .',
#    'tokens': ['a',
#     'high',
#     'mail',
#     'response',
#     'rate',
#     'is',
#     'key',
#     'to',
#     'a',
#     'successful',
#     'census',
#     'because',
#     'it',
#     'helps',
#     'the',
#     'bureau',
#     'obtain',
#     'more',
#     'accurate',
#     'data',
#     'and',
#     'reduce',
#     'what',
#     'has',
#     'been',
#     'an',
#     'error',
#     '-',
#     'prone',
#     'and',
#     'costly',
#     'nonresponse',
#     'follow',
#     '-',
#     'up',
#     'workload',
#     '.'],
#    'sentence_id': 28,
#    'word_count': 37},
#   {'text': 'the bureau is anticipating a mail response rate of 61 percent ; however , achieving this level of public participation will be a formidable task .',
#    'tokens': ['the',
#     'bureau',
#     'is',
#     'anticipating',
#     'a',
#     'mail',
#     'response',
#     'rate',
#     'of',
#     '61',
#     'percent',
#     ';',
#     'however',
#     ',',
#     'achieving',
#     'this',
#     'level',
#     'of',
#     'public',
#     'participation',
#     'will',
#     'be',
#     'a',
#     'formidable',
#     'task',
#     '.'],
#    'sentence_id': 29,
#    'word_count': 26},
#   {'text': 'the mail response rate has declined with each decennial census since the bureau first initiated a national mailout / mailback approach in 1970 .',
#    'tokens': ['the',
#     'mail',
#     'response',
#     'rate',
#     'has',
#     'declined',
#     'with',
#     'each',
#     'decennial',
#     'census',
#     'since',
#     'the',
#     'bureau',
#     'first',
#     'initiated',
#     'a',
#     'national',
#     'mailout',
#     '/',
#     'mailback',
#     'approach',
#     'in',
#     '1970',
#     '.'],
#    'sentence_id': 30,
#    'word_count': 24},
#   {'text': 'in 1970 , the bureau achieved a 78-percent response rate .',
#    'tokens': ['in',
#     '1970',
#     ',',
#     'the',
#     'bureau',
#     'achieved',
#     'a',
#     '78-percent',
#     'response',
#     'rate',
#     '.'],
#    'sentence_id': 31,
#    'word_count': 11},
#   {'text': 'the response rate declined to 70 percent in 1980 , and 65 percent in 1990 .',
#    'tokens': ['the',
#     'response',
#     'rate',
#     'declined',
#     'to',
#     '70',
#     'percent',
#     'in',
#     '1980',
#     ',',
#     'and',
#     '65',
#     'percent',
#     'in',
#     '1990',
#     '.'],
#    'sentence_id': 32,
#    'word_count': 16},
#   {'text': 'this declining trend is due , in part , to various demographic , attitudinal , and other factors , such as concerns over privacy , mistrust of government , more complex living arrangements , and a proliferation of unsolicited mail and surveys .',
#    'tokens': ['this',
#     'declining',
#     'trend',
#     'is',
#     'due',
#     ',',
#     'in',
#     'part',
#     ',',
#     'to',
#     'various',
#     'demographic',
#     ',',
#     'attitudinal',
#     ',',
#     'and',
#     'other',
#     'factors',
#     ',',
#     'such',
#     'as',
#     'concerns',
#     'over',
#     'privacy',
#     ',',
#     'mistrust',
#     'of',
#     'government',
#     ',',
#     'more',
#     'complex',
#     'living',
#     'arrangements',
#     ',',
#     'and',
#     'a',
#     'proliferation',
#     'of',
#     'unsolicited',
#     'mail',
#     'and',
#     'surveys',
#     '.'],
#    'sentence_id': 33,
#    'word_count': 43},
#   {'text': 'to help boost public participation in the census , the bureau has instituted an outreach and promotion campaign that is as ambitious as it is diverse .',
#    'tokens': ['to',
#     'help',
#     'boost',
#     'public',
#     'participation',
#     'in',
#     'the',
#     'census',
#     ',',
#     'the',
#     'bureau',
#     'has',
#     'instituted',
#     'an',
#     'outreach',
#     'and',
#     'promotion',
#     'campaign',
#     'that',
#     'is',
#     'as',
#     'ambitious',
#     'as',
#     'it',
#     'is',
#     'diverse',
#     '.'],
#    'sentence_id': 34,
#    'word_count': 27},
#   {'text': 'at the national level , the bureau hired a consortium of private - sector advertising agencies , led by young & rubicam , to develop an extensive paid advertising program for the 2000 census .',
#    'tokens': ['at',
#     'the',
#     'national',
#     'level',
#     ',',
#     'the',
#     'bureau',
#     'hired',
#     'a',
#     'consortium',
#     'of',
#     'private',
#     '-',
#     'sector',
#     'advertising',
#     'agencies',
#     ',',
#     'led',
#     'by',
#     'young',
#     '&',
#     'rubicam',
#     ',',
#     'to',
#     'develop',
#     'an',
#     'extensive',
#     'paid',
#     'advertising',
#     'program',
#     'for',
#     'the',
#     '2000',
#     'census',
#     '.'],
#    'sentence_id': 35,
#    'word_count': 35},
#   {'text': "to date , television advertisements stressing the theme that participating in the census benefits one's community have been aired during daytime soap operas and game shows , as well as during the super bowl and a number of programs targeted to specific racial and ethnic groups .",
#    'tokens': ['to',
#     'date',
#     ',',
#     'television',
#     'advertisements',
#     'stressing',
#     'the',
#     'theme',
#     'that',
#     'participating',
#     'in',
#     'the',
#     'census',
#     'benefits',
#     'one',
#     "'s",
#     'community',
#     'have',
#     'been',
#     'aired',
#     'during',
#     'daytime',
#     'soap',
#     'operas',
#     'and',
#     'game',
#     'shows',
#     ',',
#     'as',
#     'well',
#     'as',
#     'during',
#     'the',
#     'super',
#     'bowl',
#     'and',
#     'a',
#     'number',
#     'of',
#     'programs',
#     'targeted',
#     'to',
#     'specific',
#     'racial',
#     'and',
#     'ethnic',
#     'groups',
#     '.'],
#    'sentence_id': 36,
#    'word_count': 48},
#   {'text': 'as for print media , advertisements have appeared in such diverse publications as tv guide , ebony , korea times , and india today .',
#    'tokens': ['as',
#     'for',
#     'print',
#     'media',
#     ',',
#     'advertisements',
#     'have',
#     'appeared',
#     'in',
#     'such',
#     'diverse',
#     'publications',
#     'as',
#     'tv',
#     'guide',
#     ',',
#     'ebony',
#     ',',
#     'korea',
#     'times',
#     ',',
#     'and',
#     'india',
#     'today',
#     '.'],
#    'sentence_id': 37,
#    'word_count': 25},
#   {'text': 'the bureau estimates it will spend about $167 million on the paid advertising campaign in fiscal years 1998 through 2000 , of which $102.8 million was allocated for media buys in fiscal years 1999 and 2000 .',
#    'tokens': ['the',
#     'bureau',
#     'estimates',
#     'it',
#     'will',
#     'spend',
#     'about',
#     '$',
#     '167',
#     'million',
#     'on',
#     'the',
#     'paid',
#     'advertising',
#     'campaign',
#     'in',
#     'fiscal',
#     'years',
#     '1998',
#     'through',
#     '2000',
#     ',',
#     'of',
#     'which',
#     '$',
#     '102.8',
#     'million',
#     'was',
#     'allocated',
#     'for',
#     'media',
#     'buys',
#     'in',
#     'fiscal',
#     'years',
#     '1999',
#     'and',
#     '2000',
#     '.'],
#    'sentence_id': 38,
#    'word_count': 39},
#   {'text': 'at the local level , the bureau has secured partnerships with local governments , community groups , businesses , and nongovernmental organizations to promote the census at the grassroots level .',
#    'tokens': ['at',
#     'the',
#     'local',
#     'level',
#     ',',
#     'the',
#     'bureau',
#     'has',
#     'secured',
#     'partnerships',
#     'with',
#     'local',
#     'governments',
#     ',',
#     'community',
#     'groups',
#     ',',
#     'businesses',
#     ',',
#     'and',
#     'nongovernmental',
#     'organizations',
#     'to',
#     'promote',
#     'the',
#     'census',
#     'at',
#     'the',
#     'grassroots',
#     'level',
#     '.'],
#    'sentence_id': 39,
#    'word_count': 31},
#   {'text': 'the bureau reports that it has secured around 55,000 such agreements to date .',
#    'tokens': ['the',
#     'bureau',
#     'reports',
#     'that',
#     'it',
#     'has',
#     'secured',
#     'around',
#     '55,000',
#     'such',
#     'agreements',
#     'to',
#     'date',
#     '.'],
#    'sentence_id': 40,
#    'word_count': 14},
#   {'text': "the bureau's aggressive outreach and promotion initiatives face several hurdles .",
#    'tokens': ['the',
#     'bureau',
#     "'s",
#     'aggressive',
#     'outreach',
#     'and',
#     'promotion',
#     'initiatives',
#     'face',
#     'several',
#     'hurdles',
#     '.'],
#    'sentence_id': 41,
#    'word_count': 12},
#   {'text': "first , rather than simply raising the public's awareness of the census , the bureau must actually motivate people to complete a census questionnaire and return it on time .",
#    'tokens': ['first',
#     ',',
#     'rather',
#     'than',
#     'simply',
#     'raising',
#     'the',
#     'public',
#     "'s",
#     'awareness',
#     'of',
#     'the',
#     'census',
#     ',',
#     'the',
#     'bureau',
#     'must',
#     'actually',
#     'motivate',
#     'people',
#     'to',
#     'complete',
#     'a',
#     'census',
#     'questionnaire',
#     'and',
#     'return',
#     'it',
#     'on',
#     'time',
#     '.'],
#    'sentence_id': 42,
#    'word_count': 31},
#   {'text': "this gap between awareness of the census , on the one hand , and actually responding , on the other , was evident during the 1990 census when the public's high level of awareness was not matched by a similarly high mail response rate .",
#    'tokens': ['this',
#     'gap',
#     'between',
#     'awareness',
#     'of',
#     'the',
#     'census',
#     ',',
#     'on',
#     'the',
#     'one',
#     'hand',
#     ',',
#     'and',
#     'actually',
#     'responding',
#     ',',
#     'on',
#     'the',
#     'other',
#     ',',
#     'was',
#     'evident',
#     'during',
#     'the',
#     '1990',
#     'census',
#     'when',
#     'the',
#     'public',
#     "'s",
#     'high',
#     'level',
#     'of',
#     'awareness',
#     'was',
#     'not',
#     'matched',
#     'by',
#     'a',
#     'similarly',
#     'high',
#     'mail',
#     'response',
#     'rate',
#     '.'],
#    'sentence_id': 43,
#    'word_count': 46},
#   {'text': 'in fact , the bureau found that although 93 percent of the population reported being aware of the census , the mail response rate was just 65 percent .',
#    'tokens': ['in',
#     'fact',
#     ',',
#     'the',
#     'bureau',
#     'found',
#     'that',
#     'although',
#     '93',
#     'percent',
#     'of',
#     'the',
#     'population',
#     'reported',
#     'being',
#     'aware',
#     'of',
#     'the',
#     'census',
#     ',',
#     'the',
#     'mail',
#     'response',
#     'rate',
#     'was',
#     'just',
#     '65',
#     'percent',
#     '.'],
#    'sentence_id': 44,
#    'word_count': 29},
#   {'text': "unfortunately , data from the 1998 dress rehearsal suggest that the bureau's promotional efforts did not bridge this motivational gap .",
#    'tokens': ['unfortunately',
#     ',',
#     'data',
#     'from',
#     'the',
#     '1998',
#     'dress',
#     'rehearsal',
#     'suggest',
#     'that',
#     'the',
#     'bureau',
#     "'s",
#     'promotional',
#     'efforts',
#     'did',
#     'not',
#     'bridge',
#     'this',
#     'motivational',
#     'gap',
#     '.'],
#    'sentence_id': 45,
#    'word_count': 22},
#   {'text': 'although a bureau evaluation found that about 90 percent of the residents in the south carolina and sacramento dress rehearsal sites were aware of the census , the mail response rate at both sites was around 55 percent .',
#    'tokens': ['although',
#     'a',
#     'bureau',
#     'evaluation',
#     'found',
#     'that',
#     'about',
#     '90',
#     'percent',
#     'of',
#     'the',
#     'residents',
#     'in',
#     'the',
#     'south',
#     'carolina',
#     'and',
#     'sacramento',
#     'dress',
#     'rehearsal',
#     'sites',
#     'were',
#     'aware',
#     'of',
#     'the',
#     'census',
#     ',',
#     'the',
#     'mail',
#     'response',
#     'rate',
#     'at',
#     'both',
#     'sites',
#     'was',
#     'around',
#     '55',
#     'percent',
#     '.'],
#    'sentence_id': 46,
#    'word_count': 39},
#   {'text': 'second , the bureau expanded and enhanced the paid advertising campaign following the dress rehearsal ( the most intensive phase of the campaign began earlier this month ) .',
#    'tokens': ['second',
#     ',',
#     'the',
#     'bureau',
#     'expanded',
#     'and',
#     'enhanced',
#     'the',
#     'paid',
#     'advertising',
#     'campaign',
#     'following',
#     'the',
#     'dress',
#     'rehearsal',
#     '(',
#     'the',
#     'most',
#     'intensive',
#     'phase',
#     'of',
#     'the',
#     'campaign',
#     'began',
#     'earlier',
#     'this',
#     'month',
#     ')',
#     '.'],
#    'sentence_id': 47,
#    'word_count': 29},
#   {'text': "however , the impact that this additional advertising might have on people's willingness to respond to the census is difficult to predict .",
#    'tokens': ['however',
#     ',',
#     'the',
#     'impact',
#     'that',
#     'this',
#     'additional',
#     'advertising',
#     'might',
#     'have',
#     'on',
#     'people',
#     "'s",
#     'willingness',
#     'to',
#     'respond',
#     'to',
#     'the',
#     'census',
#     'is',
#     'difficult',
#     'to',
#     'predict',
#     '.'],
#    'sentence_id': 48,
#    'word_count': 24},
#   {'text': 'according to the bureau , there did not appear to be a direct relationship between exposure to advertising during the dress rehearsal and the likelihood of returning a census form .',
#    'tokens': ['according',
#     'to',
#     'the',
#     'bureau',
#     ',',
#     'there',
#     'did',
#     'not',
#     'appear',
#     'to',
#     'be',
#     'a',
#     'direct',
#     'relationship',
#     'between',
#     'exposure',
#     'to',
#     'advertising',
#     'during',
#     'the',
#     'dress',
#     'rehearsal',
#     'and',
#     'the',
#     'likelihood',
#     'of',
#     'returning',
#     'a',
#     'census',
#     'form',
#     '.'],
#    'sentence_id': 49,
#    'word_count': 31},
#   {'text': 'however , the bureau suspects that the campaign had an “indirect effect” on public response to the census in that the campaign may have made people expect the census form in the mail , which in turn increased the likelihood that they would return it .',
#    'tokens': ['however',
#     ',',
#     'the',
#     'bureau',
#     'suspects',
#     'that',
#     'the',
#     'campaign',
#     'had',
#     'an',
#     '“',
#     'indirect',
#     'effect',
#     '”',
#     'on',
#     'public',
#     'response',
#     'to',
#     'the',
#     'census',
#     'in',
#     'that',
#     'the',
#     'campaign',
#     'may',
#     'have',
#     'made',
#     'people',
#     'expect',
#     'the',
#     'census',
#     'form',
#     'in',
#     'the',
#     'mail',
#     ',',
#     'which',
#     'in',
#     'turn',
#     'increased',
#     'the',
#     'likelihood',
#     'that',
#     'they',
#     'would',
#     'return',
#     'it',
#     '.'],
#    'sentence_id': 50,
#    'word_count': 48},
#   {'text': 'traditional advertising media .',
#    'tokens': ['traditional', 'advertising', 'media', '.'],
#    'sentence_id': 51,
#    'word_count': 4},
#   {'text': 'thus , while the bureau has formed partnerships with a number of religious , service , community , and other organizations , the bureau believes that complete count committees are key to persuading everyone to respond .',
#    'tokens': ['thus',
#     ',',
#     'while',
#     'the',
#     'bureau',
#     'has',
#     'formed',
#     'partnerships',
#     'with',
#     'a',
#     'number',
#     'of',
#     'religious',
#     ',',
#     'service',
#     ',',
#     'community',
#     ',',
#     'and',
#     'other',
#     'organizations',
#     ',',
#     'the',
#     'bureau',
#     'believes',
#     'that',
#     'complete',
#     'count',
#     'committees',
#     'are',
#     'key',
#     'to',
#     'persuading',
#     'everyone',
#     'to',
#     'respond',
#     '.'],
#    'sentence_id': 52,
#    'word_count': 37},
#   {'text': 'to date , based on our recent interviews with officials from several regional census offices , a number of communities appear to be aggressively supporting the census .',
#    'tokens': ['to',
#     'date',
#     ',',
#     'based',
#     'on',
#     'our',
#     'recent',
#     'interviews',
#     'with',
#     'officials',
#     'from',
#     'several',
#     'regional',
#     'census',
#     'offices',
#     ',',
#     'a',
#     'number',
#     'of',
#     'communities',
#     'appear',
#     'to',
#     'be',
#     'aggressively',
#     'supporting',
#     'the',
#     'census',
#     '.'],
#    'sentence_id': 53,
#    'word_count': 28},
#   {'text': 'for example , some health clinics in rural kentucky are showing census videos in waiting rooms , and some state and local governments have allocated money for partnerships and advertising in local media , while others have set up web sites containing information on the census and census employment opportunities .',
#    'tokens': ['for',
#     'example',
#     ',',
#     'some',
#     'health',
#     'clinics',
#     'in',
#     'rural',
#     'kentucky',
#     'are',
#     'showing',
#     'census',
#     'videos',
#     'in',
#     'waiting',
#     'rooms',
#     ',',
#     'and',
#     'some',
#     'state',
#     'and',
#     'local',
#     'governments',
#     'have',
#     'allocated',
#     'money',
#     'for',
#     'partnerships',
#     'and',
#     'advertising',
#     'in',
#     'local',
#     'media',
#     ',',
#     'while',
#     'others',
#     'have',
#     'set',
#     'up',
#     'web',
#     'sites',
#     'containing',
#     'information',
#     'on',
#     'the',
#     'census',
#     'and',
#     'census',
#     'employment',
#     'opportunities',
#     '.'],
#    'sentence_id': 54,
#    'word_count': 51},
#   {'text': 'however , the level of activity and support for the census is likely to vary across the country , in part because of a lack of resources .',
#    'tokens': ['however',
#     ',',
#     'the',
#     'level',
#     'of',
#     'activity',
#     'and',
#     'support',
#     'for',
#     'the',
#     'census',
#     'is',
#     'likely',
#     'to',
#     'vary',
#     'across',
#     'the',
#     'country',
#     ',',
#     'in',
#     'part',
#     'because',
#     'of',
#     'a',
#     'lack',
#     'of',
#     'resources',
#     '.'],
#    'sentence_id': 55,
#    'word_count': 28},
#   {'text': 'we found that during the dress rehearsal the committees often lacked the money , people , and / or expertise to launch an adequate marketing effort .',
#    'tokens': ['we',
#     'found',
#     'that',
#     'during',
#     'the',
#     'dress',
#     'rehearsal',
#     'the',
#     'committees',
#     'often',
#     'lacked',
#     'the',
#     'money',
#     ',',
#     'people',
#     ',',
#     'and',
#     '/',
#     'or',
#     'expertise',
#     'to',
#     'launch',
#     'an',
#     'adequate',
#     'marketing',
#     'effort',
#     '.'],
#    'sentence_id': 56,
#    'word_count': 27},
#   {'text': 'with respect to money , officials representing 9 of the 14 local governments participating in the dress rehearsal told us that they were unable or unwilling to fund promotional activities .',
#    'tokens': ['with',
#     'respect',
#     'to',
#     'money',
#     ',',
#     'officials',
#     'representing',
#     '9',
#     'of',
#     'the',
#     '14',
#     'local',
#     'governments',
#     'participating',
#     'in',
#     'the',
#     'dress',
#     'rehearsal',
#     'told',
#     'us',
#     'that',
#     'they',
#     'were',
#     'unable',
#     'or',
#     'unwilling',
#     'to',
#     'fund',
#     'promotional',
#     'activities',
#     '.'],
#    'sentence_id': 57,
#    'word_count': 31},
#   {'text': 'some local governments also had difficulty getting staff to volunteer to help plan and organize promotional activities , while others lacked the experience and knowledge to market the census .',
#    'tokens': ['some',
#     'local',
#     'governments',
#     'also',
#     'had',
#     'difficulty',
#     'getting',
#     'staff',
#     'to',
#     'volunteer',
#     'to',
#     'help',
#     'plan',
#     'and',
#     'organize',
#     'promotional',
#     'activities',
#     ',',
#     'while',
#     'others',
#     'lacked',
#     'the',
#     'experience',
#     'and',
#     'knowledge',
#     'to',
#     'market',
#     'the',
#     'census',
#     '.'],
#    'sentence_id': 58,
#    'word_count': 30},
#   {'text': 'the bureau has also hired 613 partnership specialists to help local groups initiate and sustain grassroots marketing activities , such as the complete count committees .',
#    'tokens': ['the',
#     'bureau',
#     'has',
#     'also',
#     'hired',
#     '613',
#     'partnership',
#     'specialists',
#     'to',
#     'help',
#     'local',
#     'groups',
#     'initiate',
#     'and',
#     'sustain',
#     'grassroots',
#     'marketing',
#     'activities',
#     ',',
#     'such',
#     'as',
#     'the',
#     'complete',
#     'count',
#     'committees',
#     '.'],
#    'sentence_id': 59,
#    'word_count': 26},
#   {'text': 'however , based on the dress rehearsal experience , these partnership specialists may be spread too thin to offer meaningful support .',
#    'tokens': ['however',
#     ',',
#     'based',
#     'on',
#     'the',
#     'dress',
#     'rehearsal',
#     'experience',
#     ',',
#     'these',
#     'partnership',
#     'specialists',
#     'may',
#     'be',
#     'spread',
#     'too',
#     'thin',
#     'to',
#     'offer',
#     'meaningful',
#     'support',
#     '.'],
#    'sentence_id': 60,
#    'word_count': 22},
#   {'text': 'according to the bureau , there are now about 12,000 complete count committees .',
#    'tokens': ['according',
#     'to',
#     'the',
#     'bureau',
#     ',',
#     'there',
#     'are',
#     'now',
#     'about',
#     '12,000',
#     'complete',
#     'count',
#     'committees',
#     '.'],
#    'sentence_id': 61,
#    'word_count': 14},
#   {'text': 'thus , on average , each partnership specialist is responsible for assisting approximately 20 committees .',
#    'tokens': ['thus',
#     ',',
#     'on',
#     'average',
#     ',',
#     'each',
#     'partnership',
#     'specialist',
#     'is',
#     'responsible',
#     'for',
#     'assisting',
#     'approximately',
#     '20',
#     'committees',
#     '.'],
#    'sentence_id': 62,
#    'word_count': 16},
#   {'text': "by comparison , during the south carolina dress rehearsal , some committees never formed , while others became inactive , partly because the bureau's two partnership specialists were responsible for assisting an average of six local governments .",
#    'tokens': ['by',
#     'comparison',
#     ',',
#     'during',
#     'the',
#     'south',
#     'carolina',
#     'dress',
#     'rehearsal',
#     ',',
#     'some',
#     'committees',
#     'never',
#     'formed',
#     ',',
#     'while',
#     'others',
#     'became',
#     'inactive',
#     ',',
#     'partly',
#     'because',
#     'the',
#     'bureau',
#     "'s",
#     'two',
#     'partnership',
#     'specialists',
#     'were',
#     'responsible',
#     'for',
#     'assisting',
#     'an',
#     'average',
#     'of',
#     'six',
#     'local',
#     'governments',
#     '.'],
#    'sentence_id': 63,
#    'word_count': 39},
#   {'text': "initiating and maintaining the efforts of the bureau's thousands of additional local partners will stretch the partnership specialists' workload still further .",
#    'tokens': ['initiating',
#     'and',
#     'maintaining',
#     'the',
#     'efforts',
#     'of',
#     'the',
#     'bureau',
#     "'s",
#     'thousands',
#     'of',
#     'additional',
#     'local',
#     'partners',
#     'will',
#     'stretch',
#     'the',
#     'partnership',
#     'specialists',
#     "'",
#     'workload',
#     'still',
#     'further',
#     '.'],
#    'sentence_id': 64,
#    'word_count': 24},
#   {'text': "consequently , it is likely that the results of the bureau's local outreach and promotion efforts will be inconsistent .",
#    'tokens': ['consequently',
#     ',',
#     'it',
#     'is',
#     'likely',
#     'that',
#     'the',
#     'results',
#     'of',
#     'the',
#     'bureau',
#     "'s",
#     'local',
#     'outreach',
#     'and',
#     'promotion',
#     'efforts',
#     'will',
#     'be',
#     'inconsistent',
#     '.'],
#    'sentence_id': 65,
#    'word_count': 21},
#   {'text': 'operations .',
#    'tokens': ['operations', '.'],
#    'sentence_id': 66,
#    'word_count': 2},
#   {'text': 'the bureau will be challenged to complete nonresponse follow - up on schedule without compromising data quality , and to adequately staff nonresponse follow - up operations .',
#    'tokens': ['the',
#     'bureau',
#     'will',
#     'be',
#     'challenged',
#     'to',
#     'complete',
#     'nonresponse',
#     'follow',
#     '-',
#     'up',
#     'on',
#     'schedule',
#     'without',
#     'compromising',
#     'data',
#     'quality',
#     ',',
#     'and',
#     'to',
#     'adequately',
#     'staff',
#     'nonresponse',
#     'follow',
#     '-',
#     'up',
#     'operations',
#     '.'],
#    'sentence_id': 67,
#    'word_count': 28},
#   {'text': 'with regard to completing nonresponse follow - up on schedule , if the bureau achieves its anticipated 61-percent mail response rate , enumerators will need to follow up on about 46 million of the more than 119 million housing units estimated to be in the nation .',
#    'tokens': ['with',
#     'regard',
#     'to',
#     'completing',
#     'nonresponse',
#     'follow',
#     '-',
#     'up',
#     'on',
#     'schedule',
#     ',',
#     'if',
#     'the',
#     'bureau',
#     'achieves',
#     'its',
#     'anticipated',
#     '61-percent',
#     'mail',
#     'response',
#     'rate',
#     ',',
#     'enumerators',
#     'will',
#     'need',
#     'to',
#     'follow',
#     'up',
#     'on',
#     'about',
#     '46',
#     'million',
#     'of',
#     'the',
#     'more',
#     'than',
#     '119',
#     'million',
#     'housing',
#     'units',
#     'estimated',
#     'to',
#     'be',
#     'in',
#     'the',
#     'nation',
#     '.'],
#    'sentence_id': 68,
#    'word_count': 47},
#   {'text': 'however , completing this workload in the 10-week time frame the bureau has allotted for nonresponse follow - up could prove extremely difficult since the bureau will need to complete an average of more than 657,000 cases each day for the entire 10-week period .',
#    'tokens': ['however',
#     ',',
#     'completing',
#     'this',
#     'workload',
#     'in',
#     'the',
#     '10-week',
#     'time',
#     'frame',
#     'the',
#     'bureau',
#     'has',
#     'allotted',
#     'for',
#     'nonresponse',
#     'follow',
#     '-',
#     'up',
#     'could',
#     'prove',
#     'extremely',
#     'difficult',
#     'since',
#     'the',
#     'bureau',
#     'will',
#     'need',
#     'to',
#     'complete',
#     'an',
#     'average',
#     'of',
#     'more',
#     'than',
#     '657,000',
#     'cases',
#     'each',
#     'day',
#     'for',
#     'the',
#     'entire',
#     '10-week',
#     'period',
#     '.'],
#    'sentence_id': 69,
#    'word_count': 45},
#   {'text': "in addition , the bureau's quality assurance procedures , which call for enumerators to revisit certain households to identify and correct enumeration errors , will add more than 17,000 cases to the bureau's average daily workload .",
#    'tokens': ['in',
#     'addition',
#     ',',
#     'the',
#     'bureau',
#     "'s",
#     'quality',
#     'assurance',
#     'procedures',
#     ',',
#     'which',
#     'call',
#     'for',
#     'enumerators',
#     'to',
#     'revisit',
#     'certain',
#     'households',
#     'to',
#     'identify',
#     'and',
#     'correct',
#     'enumeration',
#     'errors',
#     ',',
#     'will',
#     'add',
#     'more',
#     'than',
#     '17,000',
#     'cases',
#     'to',
#     'the',
#     'bureau',
#     "'s",
#     'average',
#     'daily',
#     'workload',
#     '.'],
#    'sentence_id': 70,
#    'word_count': 39},
#   {'text': "sustaining this pace could prove challenging for a variety of reasons , ranging from nonrespondents' unwillingness to open their doors to enumerators to adverse local weather conditions .",
#    'tokens': ['sustaining',
#     'this',
#     'pace',
#     'could',
#     'prove',
#     'challenging',
#     'for',
#     'a',
#     'variety',
#     'of',
#     'reasons',
#     ',',
#     'ranging',
#     'from',
#     'nonrespondents',
#     "'",
#     'unwillingness',
#     'to',
#     'open',
#     'their',
#     'doors',
#     'to',
#     'enumerators',
#     'to',
#     'adverse',
#     'local',
#     'weather',
#     'conditions',
#     '.'],
#    'sentence_id': 71,
#    'word_count': 29},
#   {'text': 'by comparison , during the 1990 census , it took the bureau 14 weeks to follow up with 34 million households using essentially the same approach to nonresponse follow - up .',
#    'tokens': ['by',
#     'comparison',
#     ',',
#     'during',
#     'the',
#     '1990',
#     'census',
#     ',',
#     'it',
#     'took',
#     'the',
#     'bureau',
#     '14',
#     'weeks',
#     'to',
#     'follow',
#     'up',
#     'with',
#     '34',
#     'million',
#     'households',
#     'using',
#     'essentially',
#     'the',
#     'same',
#     'approach',
#     'to',
#     'nonresponse',
#     'follow',
#     '-',
#     'up',
#     '.'],
#    'sentence_id': 72,
#    'word_count': 32},
#   {'text': 'moreover , if the response rate proves to be less than 61 percent , past experience has shown that a lower - than - expected mail response rate can trigger a chain of events that can have significant implications for the accuracy and cost of the census .',
#    'tokens': ['moreover',
#     ',',
#     'if',
#     'the',
#     'response',
#     'rate',
#     'proves',
#     'to',
#     'be',
#     'less',
#     'than',
#     '61',
#     'percent',
#     ',',
#     'past',
#     'experience',
#     'has',
#     'shown',
#     'that',
#     'a',
#     'lower',
#     '-',
#     'than',
#     '-',
#     'expected',
#     'mail',
#     'response',
#     'rate',
#     'can',
#     'trigger',
#     'a',
#     'chain',
#     'of',
#     'events',
#     'that',
#     'can',
#     'have',
#     'significant',
#     'implications',
#     'for',
#     'the',
#     'accuracy',
#     'and',
#     'cost',
#     'of',
#     'the',
#     'census',
#     '.'],
#    'sentence_id': 73,
#    'word_count': 48},
#   {'text': 'this was demonstrated during the 1990 census .',
#    'tokens': ['this',
#     'was',
#     'demonstrated',
#     'during',
#     'the',
#     '1990',
#     'census',
#     '.'],
#    'sentence_id': 74,
#    'word_count': 8},
#   {'text': 'the bureau had budgeted for a nonresponse follow - up workload of about 31 million cases , but because of an unexpectedly sharp decline in the mail response rate , the bureau had to follow up on an additional 3 million cases .',
#    'tokens': ['the',
#     'bureau',
#     'had',
#     'budgeted',
#     'for',
#     'a',
#     'nonresponse',
#     'follow',
#     '-',
#     'up',
#     'workload',
#     'of',
#     'about',
#     '31',
#     'million',
#     'cases',
#     ',',
#     'but',
#     'because',
#     'of',
#     'an',
#     'unexpectedly',
#     'sharp',
#     'decline',
#     'in',
#     'the',
#     'mail',
#     'response',
#     'rate',
#     ',',
#     'the',
#     'bureau',
#     'had',
#     'to',
#     'follow',
#     'up',
#     'on',
#     'an',
#     'additional',
#     '3',
#     'million',
#     'cases',
#     '.'],
#    'sentence_id': 75,
#    'word_count': 43},
#   {'text': 'the higher than expected workloads aggravated an already difficult staffing situation in which some census offices had difficulty filling all positions and enumerator productivity was lower than anticipated .',
#    'tokens': ['the',
#     'higher',
#     'than',
#     'expected',
#     'workloads',
#     'aggravated',
#     'an',
#     'already',
#     'difficult',
#     'staffing',
#     'situation',
#     'in',
#     'which',
#     'some',
#     'census',
#     'offices',
#     'had',
#     'difficulty',
#     'filling',
#     'all',
#     'positions',
#     'and',
#     'enumerator',
#     'productivity',
#     'was',
#     'lower',
#     'than',
#     'anticipated',
#     '.'],
#    'sentence_id': 76,
#    'word_count': 29},
#   {'text': "as a result , 14 weeks were required to complete the nonresponse follow - up operation , which was 8 weeks longer than the bureau's initial estimate .",
#    'tokens': ['as',
#     'a',
#     'result',
#     ',',
#     '14',
#     'weeks',
#     'were',
#     'required',
#     'to',
#     'complete',
#     'the',
#     'nonresponse',
#     'follow',
#     '-',
#     'up',
#     'operation',
#     ',',
#     'which',
#     'was',
#     '8',
#     'weeks',
#     'longer',
#     'than',
#     'the',
#     'bureau',
#     "'s",
#     'initial',
#     'estimate',
#     '.'],
#    'sentence_id': 77,
#    'word_count': 29},
#   {'text': "or 3 percentage points less than the bureau's 61-percent goal could cause serious problems .",
#    'tokens': ['or',
#     '3',
#     'percentage',
#     'points',
#     'less',
#     'than',
#     'the',
#     'bureau',
#     "'s",
#     '61-percent',
#     'goal',
#     'could',
#     'cause',
#     'serious',
#     'problems',
#     '.'],
#    'sentence_id': 78,
#    'word_count': 16},
# ...
#     'system',
#     'acceptance',
#     ',',
#     'site',
#     'acceptance',
#     ',',
#     'and',
#     'operational',
#     'tests',
#     '.'],
#    'sentence_id': 114,
#    'word_count': 12},
#   {'text': 'furthermore , the numbers of yet - to - be resolved defects in dcs 2000 were not yet showing the clear and sustained downward trend that is expected as a system begins to mature , and the yet - to - be completed development and testing activities may surface more problems .',
#    'tokens': ['furthermore',
#     ',',
#     'the',
#     'numbers',
#     'of',
#     'yet',
#     '-',
#     'to',
#     '-',
#     'be',
#     'resolved',
#     'defects',
#     'in',
#     'dcs',
#     '2000',
#     'were',
#     'not',
#     'yet',
#     'showing',
#     'the',
#     'clear',
#     'and',
#     'sustained',
#     'downward',
#     'trend',
#     'that',
#     'is',
#     'expected',
#     'as',
#     'a',
#     'system',
#     'begins',
#     'to',
#     'mature',
#     ',',
#     'and',
#     'the',
#     'yet',
#     '-',
#     'to',
#     '-',
#     'be',
#     'completed',
#     'development',
#     'and',
#     'testing',
#     'activities',
#     'may',
#     'surface',
#     'more',
#     'problems',
#     '.'],
#    'sentence_id': 115,
#    'word_count': 52},
#   {'text': 'the bureau and its dcs 2000 development contractor shared our concerns about the delivery of promised dcs 2000 capabilities on time , and in response , they were employing measures to minimize risks and to expedite the completion of dcs 2000 .',
#    'tokens': ['the',
#     'bureau',
#     'and',
#     'its',
#     'dcs',
#     '2000',
#     'development',
#     'contractor',
#     'shared',
#     'our',
#     'concerns',
#     'about',
#     'the',
#     'delivery',
#     'of',
#     'promised',
#     'dcs',
#     '2000',
#     'capabilities',
#     'on',
#     'time',
#     ',',
#     'and',
#     'in',
#     'response',
#     ',',
#     'they',
#     'were',
#     'employing',
#     'measures',
#     'to',
#     'minimize',
#     'risks',
#     'and',
#     'to',
#     'expedite',
#     'the',
#     'completion',
#     'of',
#     'dcs',
#     '2000',
#     '.'],
#    'sentence_id': 116,
#    'word_count': 42},
#   {'text': 'for example , they implemented a formal risk management program to address risks proactively , and they defined and were following processes to ensure that only those changes that were justified on the basis of costs , benefits , and risks were approved and made .',
#    'tokens': ['for',
#     'example',
#     ',',
#     'they',
#     'implemented',
#     'a',
#     'formal',
#     'risk',
#     'management',
#     'program',
#     'to',
#     'address',
#     'risks',
#     'proactively',
#     ',',
#     'and',
#     'they',
#     'defined',
#     'and',
#     'were',
#     'following',
#     'processes',
#     'to',
#     'ensure',
#     'that',
#     'only',
#     'those',
#     'changes',
#     'that',
#     'were',
#     'justified',
#     'on',
#     'the',
#     'basis',
#     'of',
#     'costs',
#     ',',
#     'benefits',
#     ',',
#     'and',
#     'risks',
#     'were',
#     'approved',
#     'and',
#     'made',
#     '.'],
#    'sentence_id': 117,
#    'word_count': 46},
#   {'text': "also , they added a test event scheduled for february 22 – 25 , just prior to the system's operational date , to evaluate , among other things , the system's capabilities in a true operational setting .",
#    'tokens': ['also',
#     ',',
#     'they',
#     'added',
#     'a',
#     'test',
#     'event',
#     'scheduled',
#     'for',
#     'february',
#     '22',
#     '–',
#     '25',
#     ',',
#     'just',
#     'prior',
#     'to',
#     'the',
#     'system',
#     "'s",
#     'operational',
#     'date',
#     ',',
#     'to',
#     'evaluate',
#     ',',
#     'among',
#     'other',
#     'things',
#     ',',
#     'the',
#     'system',
#     "'s",
#     'capabilities',
#     'in',
#     'a',
#     'true',
#     'operational',
#     'setting',
#     '.'],
#    'sentence_id': 118,
#    'word_count': 40},
#   {'text': "another factor strongly in the bureau's favor is that its development contractor has been independently assessed as having highly effective software development capabilities in such important areas as software project planning , tracking and oversight , configuration management , software quality management , and defect resolution .",
#    'tokens': ['another',
#     'factor',
#     'strongly',
#     'in',
#     'the',
#     'bureau',
#     "'s",
#     'favor',
#     'is',
#     'that',
#     'its',
#     'development',
#     'contractor',
#     'has',
#     'been',
#     'independently',
#     'assessed',
#     'as',
#     'having',
#     'highly',
#     'effective',
#     'software',
#     'development',
#     'capabilities',
#     'in',
#     'such',
#     'important',
#     'areas',
#     'as',
#     'software',
#     'project',
#     'planning',
#     ',',
#     'tracking',
#     'and',
#     'oversight',
#     ',',
#     'configuration',
#     'management',
#     ',',
#     'software',
#     'quality',
#     'management',
#     ',',
#     'and',
#     'defect',
#     'resolution',
#     '.'],
#    'sentence_id': 119,
#    'word_count': 48},
#   {'text': 'lastly , partly in response to our review , the bureau and its development contractor initiated proactive and appropriate risk management steps , such as strengthening oversight of the resolution of system defects and requirements changes .',
#    'tokens': ['lastly',
#     ',',
#     'partly',
#     'in',
#     'response',
#     'to',
#     'our',
#     'review',
#     ',',
#     'the',
#     'bureau',
#     'and',
#     'its',
#     'development',
#     'contractor',
#     'initiated',
#     'proactive',
#     'and',
#     'appropriate',
#     'risk',
#     'management',
#     'steps',
#     ',',
#     'such',
#     'as',
#     'strengthening',
#     'oversight',
#     'of',
#     'the',
#     'resolution',
#     'of',
#     'system',
#     'defects',
#     'and',
#     'requirements',
#     'changes',
#     '.'],
#    'sentence_id': 120,
#    'word_count': 37},
#   {'text': 'while these steps do not guarantee success , they should help mitigate risk and its potential impact on the program .',
#    'tokens': ['while',
#     'these',
#     'steps',
#     'do',
#     'not',
#     'guarantee',
#     'success',
#     ',',
#     'they',
#     'should',
#     'help',
#     'mitigate',
#     'risk',
#     'and',
#     'its',
#     'potential',
#     'impact',
#     'on',
#     'the',
#     'program',
#     '.'],
#    'sentence_id': 121,
#    'word_count': 21},
#   {'text': "the bureau's progress in getting its data capture processes fully operational .",
#    'tokens': ['the',
#     'bureau',
#     "'s",
#     'progress',
#     'in',
#     'getting',
#     'its',
#     'data',
#     'capture',
#     'processes',
#     'fully',
#     'operational',
#     '.'],
#    'sentence_id': 122,
#    'word_count': 13},
#   {'text': 'to help ensure an accurate and cost - effective census , we recommended in our december 1999 report that the director , bureau of the census , develop a contingency plan of actions the bureau could take to address the operational challenges that would result from a questionnaire mail response rate that was lower than anticipated .',
#    'tokens': ['to',
#     'help',
#     'ensure',
#     'an',
#     'accurate',
#     'and',
#     'cost',
#     '-',
#     'effective',
#     'census',
#     ',',
#     'we',
#     'recommended',
#     'in',
#     'our',
#     'december',
#     '1999',
#     'report',
#     'that',
#     'the',
#     'director',
#     ',',
#     'bureau',
#     'of',
#     'the',
#     'census',
#     ',',
#     'develop',
#     'a',
#     'contingency',
#     'plan',
#     'of',
#     'actions',
#     'the',
#     'bureau',
#     'could',
#     'take',
#     'to',
#     'address',
#     'the',
#     'operational',
#     'challenges',
#     'that',
#     'would',
#     'result',
#     'from',
#     'a',
#     'questionnaire',
#     'mail',
#     'response',
#     'rate',
#     'that',
#     'was',
#     'lower',
#     'than',
#     'anticipated',
#     '.'],
#    'sentence_id': 123,
#    'word_count': 57},
#   {'text': "we noted that the bureau's plan should address , at a minimum , the budgetary , scheduling , staffing , and other logistical implications of collecting data from a larger number of nonresponding households .",
#    'tokens': ['we',
#     'noted',
#     'that',
#     'the',
#     'bureau',
#     "'s",
#     'plan',
#     'should',
#     'address',
#     ',',
#     'at',
#     'a',
#     'minimum',
#     ',',
#     'the',
#     'budgetary',
#     ',',
#     'scheduling',
#     ',',
#     'staffing',
#     ',',
#     'and',
#     'other',
#     'logistical',
#     'implications',
#     'of',
#     'collecting',
#     'data',
#     'from',
#     'a',
#     'larger',
#     'number',
#     'of',
#     'nonresponding',
#     'households',
#     '.'],
#    'sentence_id': 124,
#    'word_count': 36},
#   {'text': 'for example , the contingency plan could include options and procedures to balance the pressure to meet census schedules against the need to limit the use of proxy data , and should be shared with congress .',
#    'tokens': ['for',
#     'example',
#     ',',
#     'the',
#     'contingency',
#     'plan',
#     'could',
#     'include',
#     'options',
#     'and',
#     'procedures',
#     'to',
#     'balance',
#     'the',
#     'pressure',
#     'to',
#     'meet',
#     'census',
#     'schedules',
#     'against',
#     'the',
#     'need',
#     'to',
#     'limit',
#     'the',
#     'use',
#     'of',
#     'proxy',
#     'data',
#     ',',
#     'and',
#     'should',
#     'be',
#     'shared',
#     'with',
#     'congress',
#     '.'],
#    'sentence_id': 125,
#    'word_count': 37},
#   {'text': "the uncertainties facing the bureau's data capture system make the need for a contingency plan even more compelling .",
#    'tokens': ['the',
#     'uncertainties',
#     'facing',
#     'the',
#     'bureau',
#     "'s",
#     'data',
#     'capture',
#     'system',
#     'make',
#     'the',
#     'need',
#     'for',
#     'a',
#     'contingency',
#     'plan',
#     'even',
#     'more',
#     'compelling',
#     '.'],
#    'sentence_id': 126,
#    'word_count': 20},
#   {'text': 'in response to our recommendation , the bureau has noted that the only serious contingency plan would be to request a supplemental appropriation from congress .',
#    'tokens': ['in',
#     'response',
#     'to',
#     'our',
#     'recommendation',
#     ',',
#     'the',
#     'bureau',
#     'has',
#     'noted',
#     'that',
#     'the',
#     'only',
#     'serious',
#     'contingency',
#     'plan',
#     'would',
#     'be',
#     'to',
#     'request',
#     'a',
#     'supplemental',
#     'appropriation',
#     'from',
#     'congress',
#     '.'],
#    'sentence_id': 127,
#    'word_count': 26},
#   {'text': 'however , we continue to believe that a more fully developed and publicly disclosed plan would be helpful .',
#    'tokens': ['however',
#     ',',
#     'we',
#     'continue',
#     'to',
#     'believe',
#     'that',
#     'a',
#     'more',
#     'fully',
#     'developed',
#     'and',
#     'publicly',
#     'disclosed',
#     'plan',
#     'would',
#     'be',
#     'helpful',
#     '.'],
#    'sentence_id': 128,
#    'word_count': 19},
#   {'text': "moreover , as previously noted , a margin of just 2 – 3 percentage points separates a response rate that is consistent with the bureau's goal , from one that could trigger a host of operational problems .",
#    'tokens': ['moreover',
#     ',',
#     'as',
#     'previously',
#     'noted',
#     ',',
#     'a',
#     'margin',
#     'of',
#     'just',
#     '2',
#     '–',
#     '3',
#     'percentage',
#     'points',
#     'separates',
#     'a',
#     'response',
#     'rate',
#     'that',
#     'is',
#     'consistent',
#     'with',
#     'the',
#     'bureau',
#     "'s",
#     'goal',
#     ',',
#     'from',
#     'one',
#     'that',
#     'could',
#     'trigger',
#     'a',
#     'host',
#     'of',
#     'operational',
#     'problems',
#     '.'],
#    'sentence_id': 129,
#    'word_count': 39},
#   {'text': 'thus , by focusing on the critical challenges and trade - offs that the bureau will face if it falls short of its response rate goals , events that helped compromise the success of the 1990 census could be addressed more effectively and possibly avoided .',
#    'tokens': ['thus',
#     ',',
#     'by',
#     'focusing',
#     'on',
#     'the',
#     'critical',
#     'challenges',
#     'and',
#     'trade',
#     '-',
#     'offs',
#     'that',
#     'the',
#     'bureau',
#     'will',
#     'face',
#     'if',
#     'it',
#     'falls',
#     'short',
#     'of',
#     'its',
#     'response',
#     'rate',
#     'goals',
#     ',',
#     'events',
#     'that',
#     'helped',
#     'compromise',
#     'the',
#     'success',
#     'of',
#     'the',
#     '1990',
#     'census',
#     'could',
#     'be',
#     'addressed',
#     'more',
#     'effectively',
#     'and',
#     'possibly',
#     'avoided',
#     '.'],
#    'sentence_id': 130,
#    'word_count': 46},
#   {'text': 'in summary , mr. chairman , the bureau has put forth a tremendous effort to help ensure as complete and accurate a count of the population as possible , testing and retesting its design , and making significant modifications when necessary .',
#    'tokens': ['in',
#     'summary',
#     ',',
#     'mr.',
#     'chairman',
#     ',',
#     'the',
#     'bureau',
#     'has',
#     'put',
#     'forth',
#     'a',
#     'tremendous',
#     'effort',
#     'to',
#     'help',
#     'ensure',
#     'as',
#     'complete',
#     'and',
#     'accurate',
#     'a',
#     'count',
#     'of',
#     'the',
#     'population',
#     'as',
#     'possible',
#     ',',
#     'testing',
#     'and',
#     'retesting',
#     'its',
#     'design',
#     ',',
#     'and',
#     'making',
#     'significant',
#     'modifications',
#     'when',
#     'necessary',
#     '.'],
#    'sentence_id': 131,
#    'word_count': 42},
#   {'text': "nevertheless , substantial challenges to a successful census remain , and as we have done throughout the decade , we look forward to keeping the subcommittee informed of the bureau's progress and the results of the census .",
#    'tokens': ['nevertheless',
#     ',',
#     'substantial',
#     'challenges',
#     'to',
#     'a',
#     'successful',
#     'census',
#     'remain',
#     ',',
#     'and',
#     'as',
#     'we',
#     'have',
#     'done',
#     'throughout',
#     'the',
#     'decade',
#     ',',
#     'we',
#     'look',
#     'forward',
#     'to',
#     'keeping',
#     'the',
#     'subcommittee',
#     'informed',
#     'of',
#     'the',
#     'bureau',
#     "'s",
#     'progress',
#     'and',
#     'the',
#     'results',
#     'of',
#     'the',
#     'census',
#     '.'],
#    'sentence_id': 132,
#    'word_count': 39},
#   {'text': 'mr. chairman , this concludes my prepared statement .',
#    'tokens': ['mr.',
#     'chairman',
#     ',',
#     'this',
#     'concludes',
#     'my',
#     'prepared',
#     'statement',
#     '.'],
#    'sentence_id': 133,
#    'word_count': 9},
#   {'text': 'i would be pleased to respond to any questions you or other members of the subcommittee may have .',
#    'tokens': ['i',
#     'would',
#     'be',
#     'pleased',
#     'to',
#     'respond',
#     'to',
#     'any',
#     'questions',
#     'you',
#     'or',
#     'other',
#     'members',
#     'of',
#     'the',
#     'subcommittee',
#     'may',
#     'have',
#     '.'],
#    'sentence_id': 134,
#    'word_count': 19},
#   {'text': 'for further information regarding this testimony , please contact j. christopher mihm at ( 202 ) 512-8676 .',
#    'tokens': ['for',
#     'further',
#     'information',
#     'regarding',
#     'this',
#     'testimony',
#     ',',
#     'please',
#     'contact',
#     'j.',
#     'christopher',
#     'mihm',
#     'at',
#     '(',
#     '202',
#     ')',
#     '512-8676',
#     '.'],
#    'sentence_id': 135,
#    'word_count': 18},
#   {'text': 'individuals making key contributions to this testimony included robert goldenkoff , mark bird , christina chaplain , richard hung , ty mitchell , and lynn wasielewski .',
#    'tokens': ['individuals',
#     'making',
#     'key',
#     'contributions',
#     'to',
#     'this',
#     'testimony',
#     'included',
#     'robert',
#     'goldenkoff',
#     ',',
#     'mark',
#     'bird',
#     ',',
#     'christina',
#     'chaplain',
#     ',',
#     'richard',
#     'hung',
#     ',',
#     'ty',
#     'mitchell',
#     ',',
#     'and',
#     'lynn',
#     'wasielewski',
#     '.'],
#    'sentence_id': 136,
#    'word_count': 27}],
#  'section_names': ['letter',
#   'background',
#   'the census faces significant risks',
#   'achieving the bureau’s mail response rate objective will be difficult',
#   'field follow-up efforts will be costly and may produce unreliable data',
#   'workload and schedule',
#   'proxy data',
#   'census costs',
#   'staffing',
#   'the bureau faces formidable challenges in conducting data capture operations',
#   'dcs 2000 progress and risks',
#   'data capture center operations',
#   'contingency plans could help mitigate the risks that pose a threat to a successful census'],
#  'section_lengths': [16, 10, 2, 37, 2, 10, 4, 5, 21, 2, 12, 1, 14]}

# %% [markdown]
# ### For all GAO files

# %%
path_to_json = 'gov-report/gao'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]

# %%
pbar = ProgressBar()
for d in pbar(json_files): 
    
    path = path_to_json + '/' + d
    f = open(path)
    file = json.load(f)
    f.close()
    
    out = finalFormatting(file, sectionInfo(file)[0], sectionInfo(file)[1], sectionInfo(file)[2])
    
    out_path = 'formatted-data/gao/' + d
    with open(out_path, 'w') as f:
        json.dump(out, f)
# Out:
# 100% |########################################################################|
